# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, matthews_corrcoef, roc_auc_score, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Load the dataset
dataset = pd.read_excel('Final_non_redundant_sequences.xlsx', na_filter=False)
X_data_name = 'whole_sample_dataset_esm2_t33_650M_UR50D_unified_1280_dimension.csv'
X_data = pd.read_csv(X_data_name, header=0, index_col=0, delimiter=',')
X = np.array(X_data)
y = np.array(dataset['label'])

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def build_model(input_shape):
    input = Input(input_shape)
    x = Conv1D(64, 5, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Conv1D(128, 5, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input, outputs=x)
    return model

def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

def train_model(X_train, y_train, X_test, y_test):
    input_shape = (1280, 1)
    model = build_model(input_shape)
    
    # Optimizer
    adam = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    lrate = LearningRateScheduler(step_decay)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
    mc = ModelCheckpoint('best_model_1280.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    callbacks_list = [lrate, early_stop, mc]
    
    class_weight = {0: 1, 1: 2}  # Adjust the weights as needed
    
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, callbacks=callbacks_list, batch_size=32, class_weight=class_weight)
    
    return model

# Train the model
trained_model = train_model(X_train, y_train, X_test, y_test)

# Load the best model
saved_model = load_model('best_model_1280.h5')

# Function to optimize threshold based on MCC
def optimize_threshold(y_true, y_pred_probas):
    thresholds = np.arange(0.1, 1.0, 0.05)
    best_mcc = -1
    best_threshold = 0.5
    
    for threshold in thresholds:
        y_pred = (y_pred_probas > threshold).astype(int)
        mcc = matthews_corrcoef(y_true, y_pred)
        
        if mcc > best_mcc:
            best_mcc = mcc
            best_threshold = threshold
    
    return best_threshold, best_mcc
# Out:
# Epoch 1/100
# 137/137 [==============================] - ETA: 0s - loss: 18.5700 - accuracy: 0.8109
# Epoch 1: val_accuracy improved from -inf to 0.25365, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 137/137 [==============================] - 13s 85ms/step - loss: 18.5700 - accuracy: 0.8109 - val_loss: 11.7790 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 2/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.8745
# Epoch 2: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 11s 78ms/step - loss: 0.4847 - accuracy: 0.8745 - val_loss: 12.6962 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 3/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8800
# Epoch 3: val_accuracy improved from 0.25365 to 0.25456, saving model to best_model_1280.h5
# 137/137 [==============================] - 11s 82ms/step - loss: 0.4610 - accuracy: 0.8800 - val_loss: 3.6796 - val_accuracy: 0.2546 - lr: 0.0100
# Epoch 4/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8839
# Epoch 4: val_accuracy improved from 0.25456 to 0.33759, saving model to best_model_1280.h5
# 137/137 [==============================] - 11s 84ms/step - loss: 0.4349 - accuracy: 0.8839 - val_loss: 1.9632 - val_accuracy: 0.3376 - lr: 0.0100
# Epoch 5/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.8891
# Epoch 5: val_accuracy improved from 0.33759 to 0.88139, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 85ms/step - loss: 0.4522 - accuracy: 0.8891 - val_loss: 0.3892 - val_accuracy: 0.8814 - lr: 0.0100
# Epoch 6/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.8891
# Epoch 6: val_accuracy improved from 0.88139 to 0.88777, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 84ms/step - loss: 0.4247 - accuracy: 0.8891 - val_loss: 0.3005 - val_accuracy: 0.8878 - lr: 0.0100
# Epoch 7/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.8921
# Epoch 7: val_accuracy did not improve from 0.88777
# 137/137 [==============================] - 11s 79ms/step - loss: 0.4394 - accuracy: 0.8921 - val_loss: 0.2883 - val_accuracy: 0.8878 - lr: 0.0100
# Epoch 8/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8889
# Epoch 8: val_accuracy improved from 0.88777 to 0.90420, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 84ms/step - loss: 0.4237 - accuracy: 0.8889 - val_loss: 0.2772 - val_accuracy: 0.9042 - lr: 0.0100
# Epoch 9/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.8882
# Epoch 9: val_accuracy improved from 0.90420 to 0.90602, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 84ms/step - loss: 0.4574 - accuracy: 0.8882 - val_loss: 0.2948 - val_accuracy: 0.9060 - lr: 0.0100
# Epoch 10/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.9037
# Epoch 10: val_accuracy improved from 0.90602 to 0.90876, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 85ms/step - loss: 0.3778 - accuracy: 0.9037 - val_loss: 0.2880 - val_accuracy: 0.9088 - lr: 0.0050
# Epoch 11/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.9076
# Epoch 11: val_accuracy did not improve from 0.90876
# 137/137 [==============================] - 11s 79ms/step - loss: 0.3651 - accuracy: 0.9076 - val_loss: 0.2934 - val_accuracy: 0.9042 - lr: 0.0050
# Epoch 12/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.9003
# Epoch 12: val_accuracy did not improve from 0.90876
# 137/137 [==============================] - 11s 79ms/step - loss: 0.3665 - accuracy: 0.9003 - val_loss: 0.3009 - val_accuracy: 0.8996 - lr: 0.0050
# Epoch 13/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3642 - accuracy: 0.9042
# Epoch 13: val_accuracy did not improve from 0.90876
# 137/137 [==============================] - 11s 79ms/step - loss: 0.3642 - accuracy: 0.9042 - val_loss: 0.2924 - val_accuracy: 0.9088 - lr: 0.0050
# Epoch 14/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.9049
# Epoch 14: val_accuracy did not improve from 0.90876
# 137/137 [==============================] - 11s 79ms/step - loss: 0.3472 - accuracy: 0.9049 - val_loss: 0.3225 - val_accuracy: 0.8951 - lr: 0.0050
# Epoch 15/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.9094
# Epoch 15: val_accuracy improved from 0.90876 to 0.91332, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 85ms/step - loss: 0.3392 - accuracy: 0.9094 - val_loss: 0.2992 - val_accuracy: 0.9133 - lr: 0.0050
# Epoch 16/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.9140
# Epoch 16: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 11s 80ms/step - loss: 0.3239 - accuracy: 0.9140 - val_loss: 0.2804 - val_accuracy: 0.9051 - lr: 0.0050
# Epoch 17/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.9170
# Epoch 17: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 11s 80ms/step - loss: 0.3352 - accuracy: 0.9170 - val_loss: 0.3477 - val_accuracy: 0.8777 - lr: 0.0050
# Epoch 18/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.9176
# Epoch 18: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 11s 83ms/step - loss: 0.3293 - accuracy: 0.9176 - val_loss: 0.3780 - val_accuracy: 0.8969 - lr: 0.0050
# Epoch 19/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.9195
# Epoch 19: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 12s 87ms/step - loss: 0.3177 - accuracy: 0.9195 - val_loss: 0.2858 - val_accuracy: 0.8978 - lr: 0.0050
# Epoch 20/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9245
# Epoch 20: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 12s 85ms/step - loss: 0.2913 - accuracy: 0.9245 - val_loss: 0.3259 - val_accuracy: 0.9124 - lr: 0.0025
# Epoch 21/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2818 - accuracy: 0.9272
# Epoch 21: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 11s 84ms/step - loss: 0.2818 - accuracy: 0.9272 - val_loss: 0.2908 - val_accuracy: 0.9060 - lr: 0.0025
# Epoch 22/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.9224
# Epoch 22: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 11s 83ms/step - loss: 0.2805 - accuracy: 0.9224 - val_loss: 0.2643 - val_accuracy: 0.9133 - lr: 0.0025
# Epoch 23/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9320
# Epoch 23: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 12s 87ms/step - loss: 0.2666 - accuracy: 0.9320 - val_loss: 0.2717 - val_accuracy: 0.9115 - lr: 0.0025
# Epoch 24/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9350
# Epoch 24: val_accuracy did not improve from 0.91332
# 137/137 [==============================] - 12s 85ms/step - loss: 0.2535 - accuracy: 0.9350 - val_loss: 0.2943 - val_accuracy: 0.9124 - lr: 0.0025
# Epoch 25/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2378 - accuracy: 0.9334
# Epoch 25: val_accuracy improved from 0.91332 to 0.91788, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 89ms/step - loss: 0.2378 - accuracy: 0.9334 - val_loss: 0.3229 - val_accuracy: 0.9179 - lr: 0.0025
# Epoch 26/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9293
# Epoch 26: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 11s 84ms/step - loss: 0.2531 - accuracy: 0.9293 - val_loss: 0.3140 - val_accuracy: 0.9179 - lr: 0.0025
# Epoch 27/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9327
# Epoch 27: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 11s 83ms/step - loss: 0.2405 - accuracy: 0.9327 - val_loss: 0.3100 - val_accuracy: 0.9088 - lr: 0.0025
# Epoch 28/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9325
# Epoch 28: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 12s 86ms/step - loss: 0.2380 - accuracy: 0.9325 - val_loss: 0.3104 - val_accuracy: 0.9170 - lr: 0.0025
# Epoch 29/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9368
# Epoch 29: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 12s 89ms/step - loss: 0.2459 - accuracy: 0.9368 - val_loss: 0.3053 - val_accuracy: 0.9133 - lr: 0.0025
# Epoch 30/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9373
# Epoch 30: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 12s 86ms/step - loss: 0.2237 - accuracy: 0.9373 - val_loss: 0.3344 - val_accuracy: 0.9142 - lr: 0.0012
# Epoch 31/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9382
# Epoch 31: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 11s 83ms/step - loss: 0.2115 - accuracy: 0.9382 - val_loss: 0.3302 - val_accuracy: 0.9097 - lr: 0.0012
# Epoch 32/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9464
# Epoch 32: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 12s 85ms/step - loss: 0.1928 - accuracy: 0.9464 - val_loss: 0.3294 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 33/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9473
# Epoch 33: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1963 - accuracy: 0.9473 - val_loss: 0.3388 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 34/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9493
# Epoch 34: val_accuracy improved from 0.91788 to 0.92245, saving model to best_model_1280.h5
# 137/137 [==============================] - 13s 95ms/step - loss: 0.1843 - accuracy: 0.9493 - val_loss: 0.3137 - val_accuracy: 0.9224 - lr: 0.0012
# Epoch 35/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9500
# Epoch 35: val_accuracy did not improve from 0.92245
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1819 - accuracy: 0.9500 - val_loss: 0.3452 - val_accuracy: 0.9188 - lr: 0.0012
# Epoch 36/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9487
# Epoch 36: val_accuracy did not improve from 0.92245
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1977 - accuracy: 0.9487 - val_loss: 0.3962 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 37/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9464
# Epoch 37: val_accuracy did not improve from 0.92245
# 137/137 [==============================] - 12s 88ms/step - loss: 0.1806 - accuracy: 0.9464 - val_loss: 0.4405 - val_accuracy: 0.9151 - lr: 0.0012
# Epoch 38/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9507
# Epoch 38: val_accuracy did not improve from 0.92245
# 137/137 [==============================] - 12s 87ms/step - loss: 0.1747 - accuracy: 0.9507 - val_loss: 0.3415 - val_accuracy: 0.9188 - lr: 0.0012
# Epoch 39/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9505
# Epoch 39: val_accuracy did not improve from 0.92245
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1819 - accuracy: 0.9505 - val_loss: 0.3364 - val_accuracy: 0.9206 - lr: 0.0012
# Epoch 40/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9514
# Epoch 40: val_accuracy improved from 0.92245 to 0.92427, saving model to best_model_1280.h5
# 137/137 [==============================] - 13s 92ms/step - loss: 0.1612 - accuracy: 0.9514 - val_loss: 0.3913 - val_accuracy: 0.9243 - lr: 6.2500e-04
# Epoch 41/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9585
# Epoch 41: val_accuracy improved from 0.92427 to 0.92518, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 90ms/step - loss: 0.1447 - accuracy: 0.9585 - val_loss: 0.4098 - val_accuracy: 0.9252 - lr: 6.2500e-04
# Epoch 42/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9548
# Epoch 42: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 11s 84ms/step - loss: 0.1461 - accuracy: 0.9548 - val_loss: 0.4051 - val_accuracy: 0.9243 - lr: 6.2500e-04
# Epoch 43/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9601
# Epoch 43: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 11s 84ms/step - loss: 0.1350 - accuracy: 0.9601 - val_loss: 0.3878 - val_accuracy: 0.9252 - lr: 6.2500e-04
# Epoch 44/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9601
# Epoch 44: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1299 - accuracy: 0.9601 - val_loss: 0.4044 - val_accuracy: 0.9252 - lr: 6.2500e-04
# Epoch 45/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9598
# Epoch 45: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1424 - accuracy: 0.9598 - val_loss: 0.4410 - val_accuracy: 0.9252 - lr: 6.2500e-04
# Epoch 46/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9587
# Epoch 46: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 12s 85ms/step - loss: 0.1388 - accuracy: 0.9587 - val_loss: 0.4000 - val_accuracy: 0.9206 - lr: 6.2500e-04
# Epoch 47/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9582
# Epoch 47: val_accuracy did not improve from 0.92518
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1411 - accuracy: 0.9582 - val_loss: 0.4871 - val_accuracy: 0.9142 - lr: 6.2500e-04
# Epoch 48/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9578
# Epoch 48: val_accuracy improved from 0.92518 to 0.92701, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 90ms/step - loss: 0.1424 - accuracy: 0.9578 - val_loss: 0.4117 - val_accuracy: 0.9270 - lr: 6.2500e-04
# Epoch 49/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9637
# Epoch 49: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1259 - accuracy: 0.9637 - val_loss: 0.3984 - val_accuracy: 0.9243 - lr: 6.2500e-04
# Epoch 50/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9635
# Epoch 50: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 82ms/step - loss: 0.1257 - accuracy: 0.9635 - val_loss: 0.4493 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 51/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9660
# Epoch 51: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 82ms/step - loss: 0.1156 - accuracy: 0.9660 - val_loss: 0.4920 - val_accuracy: 0.9206 - lr: 3.1250e-04
# Epoch 52/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9644
# Epoch 52: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1206 - accuracy: 0.9644 - val_loss: 0.5341 - val_accuracy: 0.9243 - lr: 3.1250e-04
# Epoch 53/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9662
# Epoch 53: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 85ms/step - loss: 0.1142 - accuracy: 0.9662 - val_loss: 0.5018 - val_accuracy: 0.9197 - lr: 3.1250e-04
# Epoch 54/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9667
# Epoch 54: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1076 - accuracy: 0.9667 - val_loss: 0.4992 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 55/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9649
# Epoch 55: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 85ms/step - loss: 0.1109 - accuracy: 0.9649 - val_loss: 0.5071 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 56/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9665
# Epoch 56: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1054 - accuracy: 0.9665 - val_loss: 0.5407 - val_accuracy: 0.9215 - lr: 3.1250e-04
# Epoch 57/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9655
# Epoch 57: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1125 - accuracy: 0.9655 - val_loss: 0.5324 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 58/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9626
# Epoch 58: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 84ms/step - loss: 0.1112 - accuracy: 0.9626 - val_loss: 0.5734 - val_accuracy: 0.9252 - lr: 3.1250e-04
# Epoch 59/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9687
# Epoch 59: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 86ms/step - loss: 0.1089 - accuracy: 0.9687 - val_loss: 0.5202 - val_accuracy: 0.9215 - lr: 3.1250e-04
# Epoch 60/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9667
# Epoch 60: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 89ms/step - loss: 0.1024 - accuracy: 0.9667 - val_loss: 0.5556 - val_accuracy: 0.9215 - lr: 1.5625e-04
# Epoch 61/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9710
# Epoch 61: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 85ms/step - loss: 0.0956 - accuracy: 0.9710 - val_loss: 0.5430 - val_accuracy: 0.9234 - lr: 1.5625e-04
# Epoch 62/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9697
# Epoch 62: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.0953 - accuracy: 0.9697 - val_loss: 0.5695 - val_accuracy: 0.9188 - lr: 1.5625e-04
# Epoch 63/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9694
# Epoch 63: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1050 - accuracy: 0.9694 - val_loss: 0.5752 - val_accuracy: 0.9206 - lr: 1.5625e-04
# Epoch 64/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9706
# Epoch 64: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 85ms/step - loss: 0.0925 - accuracy: 0.9706 - val_loss: 0.5876 - val_accuracy: 0.9188 - lr: 1.5625e-04
# Epoch 65/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9681
# Epoch 65: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 12s 87ms/step - loss: 0.0976 - accuracy: 0.9681 - val_loss: 0.5803 - val_accuracy: 0.9252 - lr: 1.5625e-04
# Epoch 66/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9715
# Epoch 66: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.0906 - accuracy: 0.9715 - val_loss: 0.5756 - val_accuracy: 0.9224 - lr: 1.5625e-04
# Epoch 67/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9706
# Epoch 67: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.0903 - accuracy: 0.9706 - val_loss: 0.6361 - val_accuracy: 0.9234 - lr: 1.5625e-04
# Epoch 68/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9665Restoring model weights from the end of the best epoch: 48.
#
# Epoch 68: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 83ms/step - loss: 0.1005 - accuracy: 0.9665 - val_loss: 0.5860 - val_accuracy: 0.9197 - lr: 1.5625e-04
# Epoch 68: early stopping

# %%
# Evaluate on the test dataset
predicted_probas_test = saved_model.predict(X_test, batch_size=32)
best_threshold_test, best_mcc_test = optimize_threshold(y_test, predicted_probas_test)
predicted_classes_test = (predicted_probas_test > best_threshold_test).astype(int)

# Calculate metrics for the test dataset with optimized threshold
accuracy_test = accuracy_score(y_test, predicted_classes_test)
sensitivity_test = recall_score(y_test, predicted_classes_test)  # Sensitivity (Recall)
TN_test, FP_test, FN_test, TP_test = confusion_matrix(y_test, predicted_classes_test).ravel()
specificity_test = TN_test / (TN_test + FP_test)  # Corrected Specificity calculation
MCC_test = matthews_corrcoef(y_test, predicted_classes_test)
auc_test = roc_auc_score(y_test, predicted_classes_test)

# Compute the correct balanced accuracy
balanced_accuracy_test = (sensitivity_test + specificity_test) / 2

# Print the adjusted results for the test dataset
print("\nOptimized Test Dataset Results:")
print(f"Accuracy (ACC): {accuracy_test}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_test}")
print(f"Sensitivity (Sn): {sensitivity_test}")
print(f"Specificity (Sp): {specificity_test}")
print(f"MCC: {MCC_test}")
print(f"AUC: {auc_test}")
print(f"True Positives (TP): {TP_test}")
print(f"False Positives (FP): {FP_test}")
print(f"True Negatives (TN): {TN_test}")
print(f"False Negatives (FN): {FN_test}")

# Print the total positive and total negative
total_positive = np.sum(y_test)
total_negative = len(y_test) - total_positive
print(f"Total Positive: {total_positive}")
print(f"Total Negative: {total_negative}")
# Out:
# 35/35 [==============================] - 0s 8ms/step
#
# Optimized Test Dataset Results:
# Accuracy (ACC): 0.9288321167883211
# Balanced Accuracy (BACC): 0.8929570280206153
# Sensitivity (Sn): 0.8201438848920863
# Specificity (Sp): 0.9657701711491442
# MCC: 0.8081918754774996
# AUC: 0.8929570280206153
# True Positives (TP): 228
# False Positives (FP): 28
# True Negatives (TN): 790
# False Negatives (FN): 50
# Total Positive: 278
# Total Negative: 818

# %%
# Evaluate on the external dataset (KELM)
dataset_external = pd.read_csv('kelm_dataset.csv', na_filter=False)
X_external_data_name = 'kelm_dataset_esm2_t33_650M_UR50D_unified_1280_dimension.csv'
X_external_data = pd.read_csv(X_external_data_name, header=0, index_col=0, delimiter=',')
X_external = np.array(X_external_data)
y_external = np.array(dataset_external['label'])

# Normalize the external dataset
X_external_normalized = scaler.transform(X_external)

# Predict probabilities for external dataset
predicted_probas_ext = saved_model.predict(X_external_normalized, batch_size=32)
best_threshold_ext, best_mcc_ext = optimize_threshold(y_external, predicted_probas_ext)
predicted_classes_ext = (predicted_probas_ext > best_threshold_ext).astype(int)

# Calculate metrics for the external dataset with optimized threshold
accuracy_ext = accuracy_score(y_external, predicted_classes_ext)
sensitivity_ext = recall_score(y_external, predicted_classes_ext)  # Sensitivity (Recall)
TN_ext, FP_ext, FN_ext, TP_ext = confusion_matrix(y_external, predicted_classes_ext).ravel()
specificity_ext = TN_ext / (TN_ext + FP_ext)  # Corrected Specificity calculation
MCC_ext = matthews_corrcoef(y_external, predicted_classes_ext)
auc_ext = roc_auc_score(y_external, predicted_classes_ext)

# Compute the correct balanced accuracy
balanced_accuracy_ext = (sensitivity_ext + specificity_ext) / 2

# Print the adjusted results for the external dataset
print("\nOptimized External Dataset (KELM) Results:")
print(f"Accuracy (ACC): {accuracy_ext}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_ext}")
print(f"Sensitivity (Sn): {sensitivity_ext}")
print(f"Specificity (Sp): {specificity_ext}")
print(f"MCC: {MCC_ext}")
print(f"AUC: {auc_ext}")
print(f"True Positives (TP): {TP_ext}")
print(f"False Positives (FP): {FP_ext}")
print(f"True Negatives (TN): {TN_ext}")
print(f"False Negatives (FN): {FN_ext}")

# Print the total positive and total negative
total_positive_ext = np.sum(y_external)
total_negative_ext = len(y_external) - total_positive_ext
print(f"Total Positive: {total_positive_ext}")
print(f"Total Negative: {total_negative_ext}")
# Out:
# 6/6 [==============================] - 0s 10ms/step
#
# Optimized External Dataset (KELM) Results:
# Accuracy (ACC): 0.8958333333333334
# Balanced Accuracy (BACC): 0.8958333333333333
# Sensitivity (Sn): 0.84375
# Specificity (Sp): 0.9479166666666666
# MCC: 0.7959970056457051
# AUC: 0.8958333333333333
# True Positives (TP): 81
# False Positives (FP): 5
# True Negatives (TN): 91
# False Negatives (FN): 15
# Total Positive: 96
# Total Negative: 96
