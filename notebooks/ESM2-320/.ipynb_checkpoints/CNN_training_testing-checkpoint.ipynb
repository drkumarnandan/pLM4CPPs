# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, matthews_corrcoef, roc_auc_score, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Load the dataset
dataset = pd.read_excel('Final_non_redundant_sequences.xlsx', na_filter=False)
X_data_name = 'whole_sample_dataset_esm2_t6_8M_UR50D_unified_320_dimension.csv'
X_data = pd.read_csv(X_data_name, header=0, index_col=0, delimiter=',')
X = np.array(X_data)
y = np.array(dataset['label'])

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def build_model(input_shape):
    input = Input(input_shape)
    x = Conv1D(64, 5, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Conv1D(128, 5, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input, outputs=x)
    return model

def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

def train_model(X_train, y_train, X_test, y_test):
    input_shape = (320, 1)
    model = build_model(input_shape)
    
    # Optimizer
    adam = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    lrate = LearningRateScheduler(step_decay)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
    mc = ModelCheckpoint('best_model_320.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    callbacks_list = [lrate, early_stop, mc]
    
    class_weight = {0: 1, 1: 2}  # Adjust the weights as needed
    
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, callbacks=callbacks_list, batch_size=32, class_weight=class_weight)
    
    return model

# Train the model
trained_model = train_model(X_train, y_train, X_test, y_test)

# Load the best model
saved_model = load_model('best_model_320.h5')

# Function to optimize threshold based on MCC
def optimize_threshold(y_true, y_pred_probas):
    thresholds = np.arange(0.1, 1.0, 0.05)
    best_mcc = -1
    best_threshold = 0.5
    
    for threshold in thresholds:
        y_pred = (y_pred_probas > threshold).astype(int)
        mcc = matthews_corrcoef(y_true, y_pred)
        
        if mcc > best_mcc:
            best_mcc = mcc
            best_threshold = threshold
    
    return best_threshold, best_mcc
# Out:
# Epoch 1/100
# 137/137 [==============================] - ETA: 0s - loss: 5.2694 - accuracy: 0.7684
# Epoch 1: val_accuracy improved from -inf to 0.25365, saving model to best_model_320.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 137/137 [==============================] - 8s 50ms/step - loss: 5.2694 - accuracy: 0.7684 - val_loss: 6.4525 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 2/100
# 137/137 [==============================] - ETA: 0s - loss: 0.5418 - accuracy: 0.8478
# Epoch 2: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 6s 46ms/step - loss: 0.5418 - accuracy: 0.8478 - val_loss: 3.1428 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 3/100
# 137/137 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8647
# Epoch 3: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 6s 46ms/step - loss: 0.5014 - accuracy: 0.8647 - val_loss: 3.1509 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 4/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.5070 - accuracy: 0.8614
# Epoch 4: val_accuracy improved from 0.25365 to 0.76734, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.5082 - accuracy: 0.8613 - val_loss: 0.6138 - val_accuracy: 0.7673 - lr: 0.0100
# Epoch 5/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4864 - accuracy: 0.8729
# Epoch 5: val_accuracy improved from 0.76734 to 0.88412, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.4859 - accuracy: 0.8729 - val_loss: 0.3139 - val_accuracy: 0.8841 - lr: 0.0100
# Epoch 6/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4723 - accuracy: 0.8699
# Epoch 6: val_accuracy improved from 0.88412 to 0.88686, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.4708 - accuracy: 0.8704 - val_loss: 0.3410 - val_accuracy: 0.8869 - lr: 0.0100
# Epoch 7/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4571 - accuracy: 0.8780
# Epoch 7: val_accuracy did not improve from 0.88686
# 137/137 [==============================] - 6s 46ms/step - loss: 0.4580 - accuracy: 0.8777 - val_loss: 0.4750 - val_accuracy: 0.8759 - lr: 0.0100
# Epoch 8/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4751 - accuracy: 0.8725
# Epoch 8: val_accuracy did not improve from 0.88686
# 137/137 [==============================] - 6s 46ms/step - loss: 0.4741 - accuracy: 0.8731 - val_loss: 0.3742 - val_accuracy: 0.8504 - lr: 0.0100
# Epoch 9/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4539 - accuracy: 0.8791
# Epoch 9: val_accuracy did not improve from 0.88686
# 137/137 [==============================] - 6s 47ms/step - loss: 0.4523 - accuracy: 0.8798 - val_loss: 0.4324 - val_accuracy: 0.8586 - lr: 0.0100
# Epoch 10/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8890
# Epoch 10: val_accuracy improved from 0.88686 to 0.89325, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 49ms/step - loss: 0.4234 - accuracy: 0.8891 - val_loss: 0.3033 - val_accuracy: 0.8932 - lr: 0.0050
# Epoch 11/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4000 - accuracy: 0.9019
# Epoch 11: val_accuracy improved from 0.89325 to 0.90055, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.4000 - accuracy: 0.9019 - val_loss: 0.3109 - val_accuracy: 0.9005 - lr: 0.0050
# Epoch 12/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3902 - accuracy: 0.9010
# Epoch 12: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 47ms/step - loss: 0.3902 - accuracy: 0.9010 - val_loss: 0.2953 - val_accuracy: 0.8896 - lr: 0.0050
# Epoch 13/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8998
# Epoch 13: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 45ms/step - loss: 0.3966 - accuracy: 0.8998 - val_loss: 0.2987 - val_accuracy: 0.8996 - lr: 0.0050
# Epoch 14/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.8985
# Epoch 14: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.4058 - accuracy: 0.8985 - val_loss: 0.2825 - val_accuracy: 0.8960 - lr: 0.0050
# Epoch 15/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.9017
# Epoch 15: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3911 - accuracy: 0.9017 - val_loss: 0.2924 - val_accuracy: 0.8942 - lr: 0.0050
# Epoch 16/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.3898 - accuracy: 0.9040
# Epoch 16: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3883 - accuracy: 0.9042 - val_loss: 0.3723 - val_accuracy: 0.8960 - lr: 0.0050
# Epoch 17/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.3713 - accuracy: 0.9083
# Epoch 17: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3699 - accuracy: 0.9087 - val_loss: 0.3181 - val_accuracy: 0.8723 - lr: 0.0050
# Epoch 18/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.9058
# Epoch 18: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3686 - accuracy: 0.9058 - val_loss: 0.2978 - val_accuracy: 0.8942 - lr: 0.0050
# Epoch 19/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.9021
# Epoch 19: val_accuracy did not improve from 0.90055
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3682 - accuracy: 0.9021 - val_loss: 0.3052 - val_accuracy: 0.8996 - lr: 0.0050
# Epoch 20/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.3307 - accuracy: 0.9170
# Epoch 20: val_accuracy improved from 0.90055 to 0.90602, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.3320 - accuracy: 0.9167 - val_loss: 0.3012 - val_accuracy: 0.9060 - lr: 0.0025
# Epoch 21/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.9154
# Epoch 21: val_accuracy improved from 0.90602 to 0.91058, saving model to best_model_320.h5
# 137/137 [==============================] - 6s 47ms/step - loss: 0.3452 - accuracy: 0.9154 - val_loss: 0.2891 - val_accuracy: 0.9106 - lr: 0.0025
# Epoch 22/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.9195
# Epoch 22: val_accuracy did not improve from 0.91058
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3265 - accuracy: 0.9195 - val_loss: 0.3024 - val_accuracy: 0.9033 - lr: 0.0025
# Epoch 23/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.3354 - accuracy: 0.9173
# Epoch 23: val_accuracy did not improve from 0.91058
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3362 - accuracy: 0.9176 - val_loss: 0.2913 - val_accuracy: 0.9060 - lr: 0.0025
# Epoch 24/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.3207 - accuracy: 0.9223
# Epoch 24: val_accuracy did not improve from 0.91058
# 137/137 [==============================] - 6s 47ms/step - loss: 0.3196 - accuracy: 0.9227 - val_loss: 0.3095 - val_accuracy: 0.9042 - lr: 0.0025
# Epoch 25/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.9254
# Epoch 25: val_accuracy improved from 0.91058 to 0.91241, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.3238 - accuracy: 0.9254 - val_loss: 0.3007 - val_accuracy: 0.9124 - lr: 0.0025
# Epoch 26/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.9231
# Epoch 26: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3161 - accuracy: 0.9231 - val_loss: 0.3020 - val_accuracy: 0.9069 - lr: 0.0025
# Epoch 27/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.9201
# Epoch 27: val_accuracy improved from 0.91241 to 0.91423, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 48ms/step - loss: 0.3188 - accuracy: 0.9201 - val_loss: 0.2951 - val_accuracy: 0.9142 - lr: 0.0025
# Epoch 28/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.9233
# Epoch 28: val_accuracy did not improve from 0.91423
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3065 - accuracy: 0.9233 - val_loss: 0.3125 - val_accuracy: 0.9115 - lr: 0.0025
# Epoch 29/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9265
# Epoch 29: val_accuracy did not improve from 0.91423
# 137/137 [==============================] - 6s 46ms/step - loss: 0.3005 - accuracy: 0.9265 - val_loss: 0.3819 - val_accuracy: 0.9051 - lr: 0.0025
# Epoch 30/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.9295
# Epoch 30: val_accuracy improved from 0.91423 to 0.91697, saving model to best_model_320.h5
# 137/137 [==============================] - 7s 49ms/step - loss: 0.2847 - accuracy: 0.9295 - val_loss: 0.3076 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 31/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2903 - accuracy: 0.9269
# Epoch 31: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 47ms/step - loss: 0.2907 - accuracy: 0.9263 - val_loss: 0.3191 - val_accuracy: 0.9124 - lr: 0.0012
# Epoch 32/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2776 - accuracy: 0.9299
# Epoch 32: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2766 - accuracy: 0.9302 - val_loss: 0.3308 - val_accuracy: 0.9133 - lr: 0.0012
# Epoch 33/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9318
# Epoch 33: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2746 - accuracy: 0.9318 - val_loss: 0.3158 - val_accuracy: 0.9151 - lr: 0.0012
# Epoch 34/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2752 - accuracy: 0.9285
# Epoch 34: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 45ms/step - loss: 0.2744 - accuracy: 0.9288 - val_loss: 0.3283 - val_accuracy: 0.9124 - lr: 0.0012
# Epoch 35/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.9350
# Epoch 35: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2672 - accuracy: 0.9350 - val_loss: 0.3373 - val_accuracy: 0.9106 - lr: 0.0012
# Epoch 36/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9395
# Epoch 36: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 47ms/step - loss: 0.2526 - accuracy: 0.9395 - val_loss: 0.3418 - val_accuracy: 0.9051 - lr: 0.0012
# Epoch 37/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2534 - accuracy: 0.9345
# Epoch 37: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2544 - accuracy: 0.9343 - val_loss: 0.3386 - val_accuracy: 0.9161 - lr: 0.0012
# Epoch 38/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.9311
# Epoch 38: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2680 - accuracy: 0.9311 - val_loss: 0.3531 - val_accuracy: 0.9106 - lr: 0.0012
# Epoch 39/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9400
# Epoch 39: val_accuracy did not improve from 0.91697
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2429 - accuracy: 0.9400 - val_loss: 0.3342 - val_accuracy: 0.9151 - lr: 0.0012
# Epoch 40/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.9411
# Epoch 40: val_accuracy improved from 0.91697 to 0.91971, saving model to best_model_320.h5
# 137/137 [==============================] - 6s 47ms/step - loss: 0.2439 - accuracy: 0.9411 - val_loss: 0.3538 - val_accuracy: 0.9197 - lr: 6.2500e-04
# Epoch 41/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9432
# Epoch 41: val_accuracy did not improve from 0.91971
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2403 - accuracy: 0.9432 - val_loss: 0.3692 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 42/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2308 - accuracy: 0.9435
# Epoch 42: val_accuracy did not improve from 0.91971
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2324 - accuracy: 0.9434 - val_loss: 0.3668 - val_accuracy: 0.9188 - lr: 6.2500e-04
# Epoch 43/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9434
# Epoch 43: val_accuracy did not improve from 0.91971
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2223 - accuracy: 0.9434 - val_loss: 0.3757 - val_accuracy: 0.9197 - lr: 6.2500e-04
# Epoch 44/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2294 - accuracy: 0.9444
# Epoch 44: val_accuracy did not improve from 0.91971
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2291 - accuracy: 0.9446 - val_loss: 0.3604 - val_accuracy: 0.9197 - lr: 6.2500e-04
# Epoch 45/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9452
# Epoch 45: val_accuracy improved from 0.91971 to 0.92336, saving model to best_model_320.h5
# 137/137 [==============================] - 6s 47ms/step - loss: 0.2299 - accuracy: 0.9452 - val_loss: 0.3687 - val_accuracy: 0.9234 - lr: 6.2500e-04
# Epoch 46/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2313 - accuracy: 0.9407
# Epoch 46: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 45ms/step - loss: 0.2305 - accuracy: 0.9407 - val_loss: 0.3756 - val_accuracy: 0.9142 - lr: 6.2500e-04
# Epoch 47/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9432
# Epoch 47: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 45ms/step - loss: 0.2224 - accuracy: 0.9432 - val_loss: 0.3763 - val_accuracy: 0.9170 - lr: 6.2500e-04
# Epoch 48/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2242 - accuracy: 0.9449
# Epoch 48: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2250 - accuracy: 0.9446 - val_loss: 0.3780 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 49/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9496
# Epoch 49: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 7s 49ms/step - loss: 0.2185 - accuracy: 0.9496 - val_loss: 0.3503 - val_accuracy: 0.9133 - lr: 6.2500e-04
# Epoch 50/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9550
# Epoch 50: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 7s 49ms/step - loss: 0.1976 - accuracy: 0.9544 - val_loss: 0.3851 - val_accuracy: 0.9179 - lr: 3.1250e-04
# Epoch 51/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9466
# Epoch 51: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 47ms/step - loss: 0.2117 - accuracy: 0.9466 - val_loss: 0.3835 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 52/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9482
# Epoch 52: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2131 - accuracy: 0.9482 - val_loss: 0.3840 - val_accuracy: 0.9206 - lr: 3.1250e-04
# Epoch 53/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2147 - accuracy: 0.9506
# Epoch 53: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2147 - accuracy: 0.9503 - val_loss: 0.4065 - val_accuracy: 0.9179 - lr: 3.1250e-04
# Epoch 54/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2122 - accuracy: 0.9490
# Epoch 54: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2132 - accuracy: 0.9487 - val_loss: 0.3861 - val_accuracy: 0.9179 - lr: 3.1250e-04
# Epoch 55/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9537
# Epoch 55: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2049 - accuracy: 0.9537 - val_loss: 0.4020 - val_accuracy: 0.9215 - lr: 3.1250e-04
# Epoch 56/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2060 - accuracy: 0.9475
# Epoch 56: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 45ms/step - loss: 0.2060 - accuracy: 0.9475 - val_loss: 0.3904 - val_accuracy: 0.9206 - lr: 3.1250e-04
# Epoch 57/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9474
# Epoch 57: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 45ms/step - loss: 0.2046 - accuracy: 0.9473 - val_loss: 0.3889 - val_accuracy: 0.9215 - lr: 3.1250e-04
# Epoch 58/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9530
# Epoch 58: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1992 - accuracy: 0.9530 - val_loss: 0.4269 - val_accuracy: 0.9197 - lr: 3.1250e-04
# Epoch 59/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9520
# Epoch 59: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1982 - accuracy: 0.9516 - val_loss: 0.4117 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 60/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9501
# Epoch 60: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2035 - accuracy: 0.9505 - val_loss: 0.4107 - val_accuracy: 0.9197 - lr: 1.5625e-04
# Epoch 61/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9506
# Epoch 61: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1982 - accuracy: 0.9505 - val_loss: 0.3983 - val_accuracy: 0.9206 - lr: 1.5625e-04
# Epoch 62/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.2079 - accuracy: 0.9474
# Epoch 62: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.2083 - accuracy: 0.9471 - val_loss: 0.4026 - val_accuracy: 0.9206 - lr: 1.5625e-04
# Epoch 63/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9553
# Epoch 63: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1868 - accuracy: 0.9553 - val_loss: 0.3956 - val_accuracy: 0.9224 - lr: 1.5625e-04
# Epoch 64/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9523
# Epoch 64: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1972 - accuracy: 0.9523 - val_loss: 0.4044 - val_accuracy: 0.9197 - lr: 1.5625e-04
# Epoch 65/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.1878 - accuracy: 0.9543Restoring model weights from the end of the best epoch: 45.
#
# Epoch 65: val_accuracy did not improve from 0.92336
# 137/137 [==============================] - 6s 46ms/step - loss: 0.1881 - accuracy: 0.9541 - val_loss: 0.4104 - val_accuracy: 0.9206 - lr: 1.5625e-04
# Epoch 65: early stopping

# %%
# Evaluate on the test dataset
predicted_probas_test = saved_model.predict(X_test, batch_size=32)
best_threshold_test, best_mcc_test = optimize_threshold(y_test, predicted_probas_test)
predicted_classes_test = (predicted_probas_test > best_threshold_test).astype(int)

# Calculate metrics for the test dataset with optimized threshold
accuracy_test = accuracy_score(y_test, predicted_classes_test)
sensitivity_test = recall_score(y_test, predicted_classes_test)  # Sensitivity (Recall)
TN_test, FP_test, FN_test, TP_test = confusion_matrix(y_test, predicted_classes_test).ravel()
specificity_test = TN_test / (TN_test + FP_test)  # Corrected Specificity calculation
MCC_test = matthews_corrcoef(y_test, predicted_classes_test)
auc_test = roc_auc_score(y_test, predicted_classes_test)

# Compute the correct balanced accuracy
balanced_accuracy_test = (sensitivity_test + specificity_test) / 2

# Print the adjusted results for the test dataset
print("\nOptimized Test Dataset Results:")
print(f"Accuracy (ACC): {accuracy_test}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_test}")
print(f"Sensitivity (Sn): {sensitivity_test}")
print(f"Specificity (Sp): {specificity_test}")
print(f"MCC: {MCC_test}")
print(f"AUC: {auc_test}")
print(f"True Positives (TP): {TP_test}")
print(f"False Positives (FP): {FP_test}")
print(f"True Negatives (TN): {TN_test}")
print(f"False Negatives (FN): {FN_test}")

# Print the total positive and total negative
total_positive = np.sum(y_test)
total_negative = len(y_test) - total_positive
print(f"Total Positive: {total_positive}")
print(f"Total Negative: {total_negative}")
# Out:
# 35/35 [==============================] - 0s 9ms/step
#
# Optimized Test Dataset Results:
# Accuracy (ACC): 0.9233576642335767
# Balanced Accuracy (BACC): 0.8928514889799652
# Sensitivity (Sn): 0.8309352517985612
# Specificity (Sp): 0.9547677261613692
# MCC: 0.7953803978466644
# AUC: 0.8928514889799651
# True Positives (TP): 231
# False Positives (FP): 37
# True Negatives (TN): 781
# False Negatives (FN): 47
# Total Positive: 278
# Total Negative: 818
