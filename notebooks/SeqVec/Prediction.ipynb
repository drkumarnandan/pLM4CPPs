# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, matthews_corrcoef, roc_auc_score, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Load the dataset
dataset = pd.read_excel('Final_non_redundant_sequences.xlsx', na_filter=False)
X_data_name = 'seqvev_whole_smaple_reduced_embeddings_file_ordered.csv'
X_data = pd.read_csv(X_data_name, header=0, index_col=0, delimiter=',')
X = np.array(X_data)
y = np.array(dataset['label'])

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def build_model(input_shape):
    input = Input(input_shape)
    x = Conv1D(64, 5, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Conv1D(128, 5, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input, outputs=x)
    return model

def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

def train_model(X_train, y_train, X_test, y_test):
    input_shape = (1024, 1)
    model = build_model(input_shape)
    
    # Optimizer
    adam = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    lrate = LearningRateScheduler(step_decay)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
    mc = ModelCheckpoint('best_model_1024-seqvec.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    callbacks_list = [lrate, early_stop, mc]
    
    class_weight = {0: 1, 1: 2}  # Adjust the weights as needed
    
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, callbacks=callbacks_list, batch_size=32, class_weight=class_weight)
    
    return model

# Train the model
trained_model = train_model(X_train, y_train, X_test, y_test)

# Load the best model
saved_model = load_model('best_model_1024-seqvec.h5')

# Function to optimize threshold based on MCC
def optimize_threshold(y_true, y_pred_probas):
    thresholds = np.arange(0.1, 1.0, 0.05)
    best_mcc = -1
    best_threshold = 0.5
    
    for threshold in thresholds:
        y_pred = (y_pred_probas > threshold).astype(int)
        mcc = matthews_corrcoef(y_true, y_pred)
        
        if mcc > best_mcc:
            best_mcc = mcc
            best_threshold = threshold
    
    return best_threshold, best_mcc
# Out:
# Epoch 1/100
# 137/137 [==============================] - ETA: 0s - loss: 12.1339 - accuracy: 0.8086
# Epoch 1: val_accuracy improved from -inf to 0.25365, saving model to best_model_1024-seqvec.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 137/137 [==============================] - 22s 151ms/step - loss: 12.1339 - accuracy: 0.8086 - val_loss: 21.4321 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 2/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.8770
# Epoch 2: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 20s 145ms/step - loss: 0.4682 - accuracy: 0.8770 - val_loss: 16.0124 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 3/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.8841
# Epoch 3: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 20s 144ms/step - loss: 0.4456 - accuracy: 0.8841 - val_loss: 2.2084 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 4/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8775
# Epoch 4: val_accuracy improved from 0.25365 to 0.36496, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.4583 - accuracy: 0.8775 - val_loss: 1.1906 - val_accuracy: 0.3650 - lr: 0.0100
# Epoch 5/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.8855
# Epoch 5: val_accuracy improved from 0.36496 to 0.89325, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.4502 - accuracy: 0.8855 - val_loss: 0.3023 - val_accuracy: 0.8932 - lr: 0.0100
# Epoch 6/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.8763
# Epoch 6: val_accuracy did not improve from 0.89325
# 137/137 [==============================] - 20s 144ms/step - loss: 0.4566 - accuracy: 0.8763 - val_loss: 0.3267 - val_accuracy: 0.8887 - lr: 0.0100
# Epoch 7/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.8898
# Epoch 7: val_accuracy improved from 0.89325 to 0.90237, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 149ms/step - loss: 0.4294 - accuracy: 0.8898 - val_loss: 0.3222 - val_accuracy: 0.9024 - lr: 0.0100
# Epoch 8/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4374 - accuracy: 0.8923
# Epoch 8: val_accuracy did not improve from 0.90237
# 137/137 [==============================] - 20s 142ms/step - loss: 0.4374 - accuracy: 0.8923 - val_loss: 0.2808 - val_accuracy: 0.8969 - lr: 0.0100
# Epoch 9/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4357 - accuracy: 0.8898
# Epoch 9: val_accuracy did not improve from 0.90237
# 137/137 [==============================] - 20s 142ms/step - loss: 0.4357 - accuracy: 0.8898 - val_loss: 0.2951 - val_accuracy: 0.8978 - lr: 0.0100
# Epoch 10/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4022 - accuracy: 0.9003
# Epoch 10: val_accuracy did not improve from 0.90237
# 137/137 [==============================] - 19s 142ms/step - loss: 0.4022 - accuracy: 0.9003 - val_loss: 0.3037 - val_accuracy: 0.9015 - lr: 0.0050
# Epoch 11/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.9097
# Epoch 11: val_accuracy did not improve from 0.90237
# 137/137 [==============================] - 20s 142ms/step - loss: 0.3564 - accuracy: 0.9097 - val_loss: 0.2796 - val_accuracy: 0.8969 - lr: 0.0050
# Epoch 12/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.9126
# Epoch 12: val_accuracy did not improve from 0.90237
# 137/137 [==============================] - 20s 143ms/step - loss: 0.3365 - accuracy: 0.9126 - val_loss: 0.2667 - val_accuracy: 0.9015 - lr: 0.0050
# Epoch 13/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.9108
# Epoch 13: val_accuracy improved from 0.90237 to 0.90511, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.3337 - accuracy: 0.9108 - val_loss: 0.2866 - val_accuracy: 0.9051 - lr: 0.0050
# Epoch 14/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.9092
# Epoch 14: val_accuracy did not improve from 0.90511
# 137/137 [==============================] - 19s 142ms/step - loss: 0.3476 - accuracy: 0.9092 - val_loss: 0.3043 - val_accuracy: 0.9042 - lr: 0.0050
# Epoch 15/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.9165
# Epoch 15: val_accuracy improved from 0.90511 to 0.90693, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.3178 - accuracy: 0.9165 - val_loss: 0.2567 - val_accuracy: 0.9069 - lr: 0.0050
# Epoch 16/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3184 - accuracy: 0.9190
# Epoch 16: val_accuracy did not improve from 0.90693
# 137/137 [==============================] - 20s 142ms/step - loss: 0.3184 - accuracy: 0.9190 - val_loss: 0.2847 - val_accuracy: 0.8996 - lr: 0.0050
# Epoch 17/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.9174
# Epoch 17: val_accuracy did not improve from 0.90693
# 137/137 [==============================] - 20s 144ms/step - loss: 0.3174 - accuracy: 0.9174 - val_loss: 0.2745 - val_accuracy: 0.9015 - lr: 0.0050
# Epoch 18/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.9233
# Epoch 18: val_accuracy did not improve from 0.90693
# 137/137 [==============================] - 20s 143ms/step - loss: 0.3176 - accuracy: 0.9233 - val_loss: 0.2637 - val_accuracy: 0.8969 - lr: 0.0050
# Epoch 19/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2945 - accuracy: 0.9270
# Epoch 19: val_accuracy did not improve from 0.90693
# 137/137 [==============================] - 20s 143ms/step - loss: 0.2945 - accuracy: 0.9270 - val_loss: 0.2988 - val_accuracy: 0.9051 - lr: 0.0050
# Epoch 20/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9354
# Epoch 20: val_accuracy improved from 0.90693 to 0.91241, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 148ms/step - loss: 0.2513 - accuracy: 0.9354 - val_loss: 0.2829 - val_accuracy: 0.9124 - lr: 0.0025
# Epoch 21/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9384
# Epoch 21: val_accuracy improved from 0.91241 to 0.91788, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.2354 - accuracy: 0.9384 - val_loss: 0.2592 - val_accuracy: 0.9179 - lr: 0.0025
# Epoch 22/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2284 - accuracy: 0.9400
# Epoch 22: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 143ms/step - loss: 0.2284 - accuracy: 0.9400 - val_loss: 0.2741 - val_accuracy: 0.9106 - lr: 0.0025
# Epoch 23/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9423
# Epoch 23: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 144ms/step - loss: 0.2263 - accuracy: 0.9423 - val_loss: 0.2635 - val_accuracy: 0.9133 - lr: 0.0025
# Epoch 24/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9468
# Epoch 24: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 143ms/step - loss: 0.2082 - accuracy: 0.9468 - val_loss: 0.2619 - val_accuracy: 0.9170 - lr: 0.0025
# Epoch 25/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9427
# Epoch 25: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1968 - accuracy: 0.9427 - val_loss: 0.2619 - val_accuracy: 0.9151 - lr: 0.0025
# Epoch 26/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2053 - accuracy: 0.9462
# Epoch 26: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 144ms/step - loss: 0.2053 - accuracy: 0.9462 - val_loss: 0.2559 - val_accuracy: 0.9179 - lr: 0.0025
# Epoch 27/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9482
# Epoch 27: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 143ms/step - loss: 0.2000 - accuracy: 0.9482 - val_loss: 0.2978 - val_accuracy: 0.9179 - lr: 0.0025
# Epoch 28/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1908 - accuracy: 0.9509
# Epoch 28: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1908 - accuracy: 0.9509 - val_loss: 0.3042 - val_accuracy: 0.9115 - lr: 0.0025
# Epoch 29/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9521
# Epoch 29: val_accuracy improved from 0.91788 to 0.92153, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 146ms/step - loss: 0.1915 - accuracy: 0.9521 - val_loss: 0.2674 - val_accuracy: 0.9215 - lr: 0.0025
# Epoch 30/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9621
# Epoch 30: val_accuracy did not improve from 0.92153
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1596 - accuracy: 0.9621 - val_loss: 0.2885 - val_accuracy: 0.9197 - lr: 0.0012
# Epoch 31/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9605
# Epoch 31: val_accuracy did not improve from 0.92153
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1542 - accuracy: 0.9605 - val_loss: 0.3357 - val_accuracy: 0.9206 - lr: 0.0012
# Epoch 32/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9624
# Epoch 32: val_accuracy improved from 0.92153 to 0.92427, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 21s 150ms/step - loss: 0.1419 - accuracy: 0.9624 - val_loss: 0.2984 - val_accuracy: 0.9243 - lr: 0.0012
# Epoch 33/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9630
# Epoch 33: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 147ms/step - loss: 0.1412 - accuracy: 0.9630 - val_loss: 0.2914 - val_accuracy: 0.9234 - lr: 0.0012
# Epoch 34/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9646
# Epoch 34: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 145ms/step - loss: 0.1342 - accuracy: 0.9646 - val_loss: 0.3138 - val_accuracy: 0.9243 - lr: 0.0012
# Epoch 35/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9662
# Epoch 35: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1260 - accuracy: 0.9662 - val_loss: 0.3413 - val_accuracy: 0.9188 - lr: 0.0012
# Epoch 36/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9653
# Epoch 36: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1264 - accuracy: 0.9653 - val_loss: 0.3229 - val_accuracy: 0.9234 - lr: 0.0012
# Epoch 37/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9660
# Epoch 37: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1235 - accuracy: 0.9660 - val_loss: 0.3608 - val_accuracy: 0.9142 - lr: 0.0012
# Epoch 38/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9665
# Epoch 38: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 142ms/step - loss: 0.1340 - accuracy: 0.9665 - val_loss: 0.3920 - val_accuracy: 0.9188 - lr: 0.0012
# Epoch 39/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9667
# Epoch 39: val_accuracy did not improve from 0.92427
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1134 - accuracy: 0.9667 - val_loss: 0.3550 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 40/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9683
# Epoch 40: val_accuracy improved from 0.92427 to 0.92609, saving model to best_model_1024-seqvec.h5
# 137/137 [==============================] - 20s 148ms/step - loss: 0.1160 - accuracy: 0.9683 - val_loss: 0.3605 - val_accuracy: 0.9261 - lr: 6.2500e-04
# Epoch 41/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9681
# Epoch 41: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1098 - accuracy: 0.9681 - val_loss: 0.3695 - val_accuracy: 0.9215 - lr: 6.2500e-04
# Epoch 42/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9735
# Epoch 42: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1025 - accuracy: 0.9735 - val_loss: 0.3697 - val_accuracy: 0.9234 - lr: 6.2500e-04
# Epoch 43/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9713
# Epoch 43: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1050 - accuracy: 0.9713 - val_loss: 0.4092 - val_accuracy: 0.9215 - lr: 6.2500e-04
# Epoch 44/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9678
# Epoch 44: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.1066 - accuracy: 0.9678 - val_loss: 0.4185 - val_accuracy: 0.9243 - lr: 6.2500e-04
# Epoch 45/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9731
# Epoch 45: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 145ms/step - loss: 0.0961 - accuracy: 0.9731 - val_loss: 0.4209 - val_accuracy: 0.9161 - lr: 6.2500e-04
# Epoch 46/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9726
# Epoch 46: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0972 - accuracy: 0.9726 - val_loss: 0.4079 - val_accuracy: 0.9197 - lr: 6.2500e-04
# Epoch 47/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9724
# Epoch 47: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 145ms/step - loss: 0.0974 - accuracy: 0.9724 - val_loss: 0.4505 - val_accuracy: 0.9197 - lr: 6.2500e-04
# Epoch 48/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9728
# Epoch 48: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 144ms/step - loss: 0.0963 - accuracy: 0.9728 - val_loss: 0.4273 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 49/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9713
# Epoch 49: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0995 - accuracy: 0.9713 - val_loss: 0.4240 - val_accuracy: 0.9215 - lr: 6.2500e-04
# Epoch 50/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9754
# Epoch 50: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 144ms/step - loss: 0.0828 - accuracy: 0.9754 - val_loss: 0.4352 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 51/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9776
# Epoch 51: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 145ms/step - loss: 0.0784 - accuracy: 0.9776 - val_loss: 0.4542 - val_accuracy: 0.9151 - lr: 3.1250e-04
# Epoch 52/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9788
# Epoch 52: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0815 - accuracy: 0.9788 - val_loss: 0.4381 - val_accuracy: 0.9170 - lr: 3.1250e-04
# Epoch 53/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9754
# Epoch 53: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 146ms/step - loss: 0.0825 - accuracy: 0.9754 - val_loss: 0.4716 - val_accuracy: 0.9179 - lr: 3.1250e-04
# Epoch 54/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9763
# Epoch 54: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 144ms/step - loss: 0.0866 - accuracy: 0.9763 - val_loss: 0.4456 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 55/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9786
# Epoch 55: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 146ms/step - loss: 0.0779 - accuracy: 0.9786 - val_loss: 0.4549 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 56/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9770
# Epoch 56: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 145ms/step - loss: 0.0746 - accuracy: 0.9770 - val_loss: 0.4646 - val_accuracy: 0.9215 - lr: 3.1250e-04
# Epoch 57/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9776
# Epoch 57: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0781 - accuracy: 0.9776 - val_loss: 0.4570 - val_accuracy: 0.9170 - lr: 3.1250e-04
# Epoch 58/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9774
# Epoch 58: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0717 - accuracy: 0.9774 - val_loss: 0.4535 - val_accuracy: 0.9206 - lr: 3.1250e-04
# Epoch 59/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9770
# Epoch 59: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0795 - accuracy: 0.9770 - val_loss: 0.4869 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 60/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9799Restoring model weights from the end of the best epoch: 40.
#
# Epoch 60: val_accuracy did not improve from 0.92609
# 137/137 [==============================] - 20s 146ms/step - loss: 0.0700 - accuracy: 0.9799 - val_loss: 0.4849 - val_accuracy: 0.9206 - lr: 1.5625e-04
# Epoch 60: early stopping

# %%
# Evaluate on the test dataset
predicted_probas_test = saved_model.predict(X_test, batch_size=32)
best_threshold_test, best_mcc_test = optimize_threshold(y_test, predicted_probas_test)
predicted_classes_test = (predicted_probas_test > best_threshold_test).astype(int)

# Calculate metrics for the test dataset with optimized threshold
accuracy_test = accuracy_score(y_test, predicted_classes_test)
sensitivity_test = recall_score(y_test, predicted_classes_test)  # Sensitivity (Recall)
TN_test, FP_test, FN_test, TP_test = confusion_matrix(y_test, predicted_classes_test).ravel()
specificity_test = TN_test / (TN_test + FP_test)  # Corrected Specificity calculation
MCC_test = matthews_corrcoef(y_test, predicted_classes_test)
auc_test = roc_auc_score(y_test, predicted_classes_test)

# Compute the correct balanced accuracy
balanced_accuracy_test = (sensitivity_test + specificity_test) / 2

# Print the adjusted results for the test dataset
print("\nOptimized Test Dataset Results:")
print(f"Accuracy (ACC): {accuracy_test}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_test}")
print(f"Sensitivity (Sn): {sensitivity_test}")
print(f"Specificity (Sp): {specificity_test}")
print(f"MCC: {MCC_test}")
print(f"AUC: {auc_test}")
print(f"True Positives (TP): {TP_test}")
print(f"False Positives (FP): {FP_test}")
print(f"True Negatives (TN): {TN_test}")
print(f"False Negatives (FN): {FN_test}")

# Print the total positive and total negative
total_positive = np.sum(y_test)
total_negative = len(y_test) - total_positive
print(f"Total Positive: {total_positive}")
print(f"Total Negative: {total_negative}")
# Out:
# 35/35 [==============================] - 1s 23ms/step
#
# Optimized Test Dataset Results:
# Accuracy (ACC): 0.9324817518248175
# Balanced Accuracy (BACC): 0.9013385868322457
# Sensitivity (Sn): 0.8381294964028777
# Specificity (Sp): 0.9645476772616137
# MCC: 0.8188536545188286
# AUC: 0.9013385868322458
# True Positives (TP): 233
# False Positives (FP): 29
# True Negatives (TN): 789
# False Negatives (FN): 45
# Total Positive: 278
# Total Negative: 818

# %%
# Evaluate on the external dataset (KELM)
dataset_external = pd.read_csv('kelm_dataset.csv', na_filter=False)
X_external_data_name = 'seqvev_kelm_data_reduced_embeddings_file_ordered.csv'
X_external_data = pd.read_csv(X_external_data_name, header=0, index_col=0, delimiter=',')
X_external = np.array(X_external_data)
y_external = np.array(dataset_external['label'])

# Normalize the external dataset
X_external_normalized = scaler.transform(X_external)

# Predict probabilities for external dataset
predicted_probas_ext = saved_model.predict(X_external_normalized, batch_size=32)
best_threshold_ext, best_mcc_ext = optimize_threshold(y_external, predicted_probas_ext)
predicted_classes_ext = (predicted_probas_ext > best_threshold_ext).astype(int)

# Calculate metrics for the external dataset with optimized threshold
accuracy_ext = accuracy_score(y_external, predicted_classes_ext)
sensitivity_ext = recall_score(y_external, predicted_classes_ext)  # Sensitivity (Recall)
TN_ext, FP_ext, FN_ext, TP_ext = confusion_matrix(y_external, predicted_classes_ext).ravel()
specificity_ext = TN_ext / (TN_ext + FP_ext)  # Corrected Specificity calculation
MCC_ext = matthews_corrcoef(y_external, predicted_classes_ext)
auc_ext = roc_auc_score(y_external, predicted_classes_ext)

# Compute the correct balanced accuracy
balanced_accuracy_ext = (sensitivity_ext + specificity_ext) / 2

# Print the adjusted results for the external dataset
print("\nOptimized External Dataset (KELM) Results:")
print(f"Accuracy (ACC): {accuracy_ext}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_ext}")
print(f"Sensitivity (Sn): {sensitivity_ext}")
print(f"Specificity (Sp): {specificity_ext}")
print(f"MCC: {MCC_ext}")
print(f"AUC: {auc_ext}")
print(f"True Positives (TP): {TP_ext}")
print(f"False Positives (FP): {FP_ext}")
print(f"True Negatives (TN): {TN_ext}")
print(f"False Negatives (FN): {FN_ext}")

# Print the total positive and total negative
total_positive_ext = np.sum(y_external)
total_negative_ext = len(y_external) - total_positive_ext
print(f"Total Positive: {total_positive_ext}")
print(f"Total Negative: {total_negative_ext}")
# Out:
# 6/6 [==============================] - 0s 25ms/step
#
# Optimized External Dataset (KELM) Results:
# Accuracy (ACC): 0.8697916666666666
# Balanced Accuracy (BACC): 0.8697916666666667
# Sensitivity (Sn): 0.8020833333333334
# Specificity (Sp): 0.9375
# MCC: 0.7464591631114137
# AUC: 0.8697916666666667
# True Positives (TP): 77
# False Positives (FP): 6
# True Negatives (TN): 90
# False Negatives (FN): 19
# Total Positive: 96
# Total Negative: 96
