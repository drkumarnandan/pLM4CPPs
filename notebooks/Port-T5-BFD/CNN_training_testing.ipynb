# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, matthews_corrcoef, roc_auc_score, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Load the dataset
dataset = pd.read_excel('Final_non_redundant_sequences.xlsx', na_filter=False)
X_data_name = 'prot_t5_xl_bfd_per_protein_embeddings.csv'
X_data = pd.read_csv(X_data_name, header=0, index_col=0, delimiter=',')
X = np.array(X_data)
y = np.array(dataset['label'])

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def build_model(input_shape):
    input = Input(input_shape)
    x = Conv1D(64, 5, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Conv1D(128, 5, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input, outputs=x)
    return model

def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

def train_model(X_train, y_train, X_test, y_test):
    input_shape = (1024, 1)
    model = build_model(input_shape)
    
    # Optimizer
    adam = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    lrate = LearningRateScheduler(step_decay)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
    mc = ModelCheckpoint('best_model_1024-bfd.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    callbacks_list = [lrate, early_stop, mc]
    
    class_weight = {0: 1, 1: 2}  # Adjust the weights as needed
    
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, callbacks=callbacks_list, batch_size=32, class_weight=class_weight)
    
    return model

# Train the model
trained_model = train_model(X_train, y_train, X_test, y_test)

# Load the best model
saved_model = load_model('best_model_1024-bfd.h5')

# Function to optimize threshold based on MCC
def optimize_threshold(y_true, y_pred_probas):
    thresholds = np.arange(0.1, 1.0, 0.05)
    best_mcc = -1
    best_threshold = 0.5
    
    for threshold in thresholds:
        y_pred = (y_pred_probas > threshold).astype(int)
        mcc = matthews_corrcoef(y_true, y_pred)
        
        if mcc > best_mcc:
            best_mcc = mcc
            best_threshold = threshold
    
    return best_threshold, best_mcc
# Out:
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 137/137 [==============================] - ETA: 0s - loss: 14.8770 - accuracy: 0.8186
# Epoch 1: val_accuracy improved from -inf to 0.25365, saving model to best_model_1024-bfd.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 137/137 [==============================] - 22s 147ms/step - loss: 14.8770 - accuracy: 0.8186 - val_loss: 8.7774 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 2/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.8809
# Epoch 2: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 19s 140ms/step - loss: 0.4533 - accuracy: 0.8809 - val_loss: 8.6482 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 3/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8887
# Epoch 3: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 19s 140ms/step - loss: 0.4265 - accuracy: 0.8887 - val_loss: 4.2164 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 4/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4236 - accuracy: 0.8896
# Epoch 4: val_accuracy improved from 0.25365 to 0.84124, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 144ms/step - loss: 0.4236 - accuracy: 0.8896 - val_loss: 0.4405 - val_accuracy: 0.8412 - lr: 0.0100
# Epoch 5/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4063 - accuracy: 0.9003
# Epoch 5: val_accuracy improved from 0.84124 to 0.89051, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 148ms/step - loss: 0.4063 - accuracy: 0.9003 - val_loss: 0.3022 - val_accuracy: 0.8905 - lr: 0.0100
# Epoch 6/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3922 - accuracy: 0.8985
# Epoch 6: val_accuracy improved from 0.89051 to 0.89234, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 146ms/step - loss: 0.3922 - accuracy: 0.8985 - val_loss: 0.3102 - val_accuracy: 0.8923 - lr: 0.0100
# Epoch 7/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3983 - accuracy: 0.9021
# Epoch 7: val_accuracy did not improve from 0.89234
# 137/137 [==============================] - 19s 142ms/step - loss: 0.3983 - accuracy: 0.9021 - val_loss: 0.2847 - val_accuracy: 0.8914 - lr: 0.0100
# Epoch 8/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8919
# Epoch 8: val_accuracy did not improve from 0.89234
# 137/137 [==============================] - 19s 140ms/step - loss: 0.4219 - accuracy: 0.8919 - val_loss: 0.3338 - val_accuracy: 0.8887 - lr: 0.0100
# Epoch 9/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8992
# Epoch 9: val_accuracy improved from 0.89234 to 0.90420, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 147ms/step - loss: 0.4097 - accuracy: 0.8992 - val_loss: 0.2911 - val_accuracy: 0.9042 - lr: 0.0100
# Epoch 10/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.9144
# Epoch 10: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 140ms/step - loss: 0.3603 - accuracy: 0.9144 - val_loss: 0.3576 - val_accuracy: 0.8850 - lr: 0.0050
# Epoch 11/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.9158
# Epoch 11: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 141ms/step - loss: 0.3448 - accuracy: 0.9158 - val_loss: 0.2968 - val_accuracy: 0.8987 - lr: 0.0050
# Epoch 12/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3439 - accuracy: 0.9185
# Epoch 12: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 141ms/step - loss: 0.3439 - accuracy: 0.9185 - val_loss: 0.2665 - val_accuracy: 0.8951 - lr: 0.0050
# Epoch 13/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.9183
# Epoch 13: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 139ms/step - loss: 0.3338 - accuracy: 0.9183 - val_loss: 0.2909 - val_accuracy: 0.9033 - lr: 0.0050
# Epoch 14/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.9252
# Epoch 14: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 140ms/step - loss: 0.3105 - accuracy: 0.9252 - val_loss: 0.2990 - val_accuracy: 0.9033 - lr: 0.0050
# Epoch 15/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.9204
# Epoch 15: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 140ms/step - loss: 0.3365 - accuracy: 0.9204 - val_loss: 0.2788 - val_accuracy: 0.8942 - lr: 0.0050
# Epoch 16/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.9170
# Epoch 16: val_accuracy did not improve from 0.90420
# 137/137 [==============================] - 19s 140ms/step - loss: 0.3314 - accuracy: 0.9170 - val_loss: 0.3155 - val_accuracy: 0.8942 - lr: 0.0050
# Epoch 17/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3172 - accuracy: 0.9229
# Epoch 17: val_accuracy improved from 0.90420 to 0.91241, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 144ms/step - loss: 0.3172 - accuracy: 0.9229 - val_loss: 0.2613 - val_accuracy: 0.9124 - lr: 0.0050
# Epoch 18/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.9213
# Epoch 18: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.3034 - accuracy: 0.9213 - val_loss: 0.2885 - val_accuracy: 0.9033 - lr: 0.0050
# Epoch 19/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.9238
# Epoch 19: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.3357 - accuracy: 0.9238 - val_loss: 0.2754 - val_accuracy: 0.9106 - lr: 0.0050
# Epoch 20/100
# 137/137 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.9279
# Epoch 20: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.3016 - accuracy: 0.9279 - val_loss: 0.3109 - val_accuracy: 0.9069 - lr: 0.0025
# Epoch 21/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9366
# Epoch 21: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.2665 - accuracy: 0.9366 - val_loss: 0.2715 - val_accuracy: 0.9097 - lr: 0.0025
# Epoch 22/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9379
# Epoch 22: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 140ms/step - loss: 0.2602 - accuracy: 0.9379 - val_loss: 0.3302 - val_accuracy: 0.9024 - lr: 0.0025
# Epoch 23/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9439
# Epoch 23: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.2361 - accuracy: 0.9439 - val_loss: 0.2825 - val_accuracy: 0.9024 - lr: 0.0025
# Epoch 24/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9478
# Epoch 24: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 142ms/step - loss: 0.2206 - accuracy: 0.9478 - val_loss: 0.2963 - val_accuracy: 0.9005 - lr: 0.0025
# Epoch 25/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9439
# Epoch 25: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 140ms/step - loss: 0.2286 - accuracy: 0.9439 - val_loss: 0.2942 - val_accuracy: 0.9115 - lr: 0.0025
# Epoch 26/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9430
# Epoch 26: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 20s 149ms/step - loss: 0.2331 - accuracy: 0.9430 - val_loss: 0.3376 - val_accuracy: 0.8996 - lr: 0.0025
# Epoch 27/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9398
# Epoch 27: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 20s 146ms/step - loss: 0.2295 - accuracy: 0.9398 - val_loss: 0.2831 - val_accuracy: 0.9097 - lr: 0.0025
# Epoch 28/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9430
# Epoch 28: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 20s 143ms/step - loss: 0.2209 - accuracy: 0.9430 - val_loss: 0.4231 - val_accuracy: 0.8750 - lr: 0.0025
# Epoch 29/100
# 137/137 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9482
# Epoch 29: val_accuracy did not improve from 0.91241
# 137/137 [==============================] - 19s 141ms/step - loss: 0.2121 - accuracy: 0.9482 - val_loss: 0.2953 - val_accuracy: 0.9078 - lr: 0.0025
# Epoch 30/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9496
# Epoch 30: val_accuracy improved from 0.91241 to 0.91788, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 145ms/step - loss: 0.1981 - accuracy: 0.9496 - val_loss: 0.2896 - val_accuracy: 0.9179 - lr: 0.0012
# Epoch 31/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9544
# Epoch 31: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1881 - accuracy: 0.9544 - val_loss: 0.3154 - val_accuracy: 0.9133 - lr: 0.0012
# Epoch 32/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9573
# Epoch 32: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1827 - accuracy: 0.9573 - val_loss: 0.2777 - val_accuracy: 0.9115 - lr: 0.0012
# Epoch 33/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9605
# Epoch 33: val_accuracy did not improve from 0.91788
# 137/137 [==============================] - 19s 141ms/step - loss: 0.1656 - accuracy: 0.9605 - val_loss: 0.3282 - val_accuracy: 0.9133 - lr: 0.0012
# Epoch 34/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9594
# Epoch 34: val_accuracy improved from 0.91788 to 0.92062, saving model to best_model_1024-bfd.h5
# 137/137 [==============================] - 20s 146ms/step - loss: 0.1670 - accuracy: 0.9594 - val_loss: 0.3428 - val_accuracy: 0.9206 - lr: 0.0012
# Epoch 35/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9619
# Epoch 35: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1561 - accuracy: 0.9619 - val_loss: 0.3614 - val_accuracy: 0.9124 - lr: 0.0012
# Epoch 36/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9614
# Epoch 36: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 141ms/step - loss: 0.1678 - accuracy: 0.9614 - val_loss: 0.3726 - val_accuracy: 0.9170 - lr: 0.0012
# Epoch 37/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9626
# Epoch 37: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1609 - accuracy: 0.9626 - val_loss: 0.3385 - val_accuracy: 0.9161 - lr: 0.0012
# Epoch 38/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9635
# Epoch 38: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 141ms/step - loss: 0.1541 - accuracy: 0.9635 - val_loss: 0.3989 - val_accuracy: 0.9161 - lr: 0.0012
# Epoch 39/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9605
# Epoch 39: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1544 - accuracy: 0.9605 - val_loss: 0.3401 - val_accuracy: 0.9124 - lr: 0.0012
# Epoch 40/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9619
# Epoch 40: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1561 - accuracy: 0.9619 - val_loss: 0.3966 - val_accuracy: 0.9124 - lr: 6.2500e-04
# Epoch 41/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9669
# Epoch 41: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1397 - accuracy: 0.9669 - val_loss: 0.4158 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 42/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9699
# Epoch 42: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1302 - accuracy: 0.9699 - val_loss: 0.4057 - val_accuracy: 0.9106 - lr: 6.2500e-04
# Epoch 43/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9681
# Epoch 43: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1263 - accuracy: 0.9681 - val_loss: 0.3845 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 44/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9733
# Epoch 44: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1142 - accuracy: 0.9733 - val_loss: 0.4196 - val_accuracy: 0.9151 - lr: 6.2500e-04
# Epoch 45/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9690
# Epoch 45: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1187 - accuracy: 0.9690 - val_loss: 0.4114 - val_accuracy: 0.9151 - lr: 6.2500e-04
# Epoch 46/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9726
# Epoch 46: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1194 - accuracy: 0.9726 - val_loss: 0.4164 - val_accuracy: 0.9188 - lr: 6.2500e-04
# Epoch 47/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9701
# Epoch 47: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1142 - accuracy: 0.9701 - val_loss: 0.4162 - val_accuracy: 0.9179 - lr: 6.2500e-04
# Epoch 48/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9744
# Epoch 48: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.1089 - accuracy: 0.9744 - val_loss: 0.4161 - val_accuracy: 0.9142 - lr: 6.2500e-04
# Epoch 49/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9690
# Epoch 49: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 142ms/step - loss: 0.1224 - accuracy: 0.9690 - val_loss: 0.4381 - val_accuracy: 0.9188 - lr: 6.2500e-04
# Epoch 50/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9790
# Epoch 50: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 20s 143ms/step - loss: 0.0953 - accuracy: 0.9790 - val_loss: 0.4546 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 51/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9781
# Epoch 51: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 141ms/step - loss: 0.0930 - accuracy: 0.9781 - val_loss: 0.4692 - val_accuracy: 0.9170 - lr: 3.1250e-04
# Epoch 52/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9790
# Epoch 52: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 141ms/step - loss: 0.0961 - accuracy: 0.9790 - val_loss: 0.4712 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 53/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9792
# Epoch 53: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 141ms/step - loss: 0.0906 - accuracy: 0.9792 - val_loss: 0.4648 - val_accuracy: 0.9188 - lr: 3.1250e-04
# Epoch 54/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9760Restoring model weights from the end of the best epoch: 34.
#
# Epoch 54: val_accuracy did not improve from 0.92062
# 137/137 [==============================] - 19s 140ms/step - loss: 0.0972 - accuracy: 0.9760 - val_loss: 0.5071 - val_accuracy: 0.9161 - lr: 3.1250e-04
# Epoch 54: early stopping

# %%
# Evaluate on the test dataset
predicted_probas_test = saved_model.predict(X_test, batch_size=32)
best_threshold_test, best_mcc_test = optimize_threshold(y_test, predicted_probas_test)
predicted_classes_test = (predicted_probas_test > best_threshold_test).astype(int)

# Calculate metrics for the test dataset with optimized threshold
accuracy_test = accuracy_score(y_test, predicted_classes_test)
sensitivity_test = recall_score(y_test, predicted_classes_test)  # Sensitivity (Recall)
TN_test, FP_test, FN_test, TP_test = confusion_matrix(y_test, predicted_classes_test).ravel()
specificity_test = TN_test / (TN_test + FP_test)  # Corrected Specificity calculation
MCC_test = matthews_corrcoef(y_test, predicted_classes_test)
auc_test = roc_auc_score(y_test, predicted_classes_test)

# Compute the correct balanced accuracy
balanced_accuracy_test = (sensitivity_test + specificity_test) / 2

# Print the adjusted results for the test dataset
print("\nOptimized Test Dataset Results:")
print(f"Accuracy (ACC): {accuracy_test}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_test}")
print(f"Sensitivity (Sn): {sensitivity_test}")
print(f"Specificity (Sp): {specificity_test}")
print(f"MCC: {MCC_test}")
print(f"AUC: {auc_test}")
print(f"True Positives (TP): {TP_test}")
print(f"False Positives (FP): {FP_test}")
print(f"True Negatives (TN): {TN_test}")
print(f"False Negatives (FN): {FN_test}")

# Print the total positive and total negative
total_positive = np.sum(y_test)
total_negative = len(y_test) - total_positive
print(f"Total Positive: {total_positive}")
print(f"Total Negative: {total_negative}")
# Out:
# 35/35 [==============================] - 1s 23ms/step
#
# Optimized Test Dataset Results:
# Accuracy (ACC): 0.9206204379562044
# Balanced Accuracy (BACC): 0.8910177481486694
# Sensitivity (Sn): 0.8309352517985612
# Specificity (Sp): 0.9511002444987775
# MCC: 0.7887037324016605
# AUC: 0.8910177481486694
# True Positives (TP): 231
# False Positives (FP): 40
# True Negatives (TN): 778
# False Negatives (FN): 47
# Total Positive: 278
# Total Negative: 818
