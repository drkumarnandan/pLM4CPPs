# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, matthews_corrcoef, roc_auc_score, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Load the dataset
dataset = pd.read_excel('Final_non_redundant_sequences.xlsx', na_filter=False)
X_data_name = 'whole_sample_dataset_esm2_t33_650M_UR50D_unified_1280_dimension.csv'
X_data = pd.read_csv(X_data_name, header=0, index_col=0, delimiter=',')
X = np.array(X_data)
y = np.array(dataset['label'])

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

def build_model(input_shape):
    input = Input(input_shape)
    x = Conv1D(64, 5, strides=1, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Conv1D(128, 5, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input, outputs=x)
    return model

def step_decay(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch) / epochs_drop))
    return lr

def train_model(X_train, y_train, X_test, y_test):
    input_shape = (1280, 1)
    model = build_model(input_shape)
    
    # Optimizer
    adam = tf.keras.optimizers.Adam(learning_rate=0.001)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    
    lrate = LearningRateScheduler(step_decay)
    early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
    mc = ModelCheckpoint('best_model_1280.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    callbacks_list = [lrate, early_stop, mc]
    
    class_weight = {0: 1, 1: 2}  # Adjust the weights as needed
    
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, callbacks=callbacks_list, batch_size=32, class_weight=class_weight)
    
    return model

# Train the model
trained_model = train_model(X_train, y_train, X_test, y_test)

# Load the best model
saved_model = load_model('best_model_1280.h5')

# Function to optimize threshold based on MCC
def optimize_threshold(y_true, y_pred_probas):
    thresholds = np.arange(0.1, 1.0, 0.05)
    best_mcc = -1
    best_threshold = 0.5
    
    for threshold in thresholds:
        y_pred = (y_pred_probas > threshold).astype(int)
        mcc = matthews_corrcoef(y_true, y_pred)
        
        if mcc > best_mcc:
            best_mcc = mcc
            best_threshold = threshold
    
    return best_threshold, best_mcc
# Out:
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 137/137 [==============================] - ETA: 0s - loss: 25.5730 - accuracy: 0.8017
# Epoch 1: val_accuracy improved from -inf to 0.25365, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 137/137 [==============================] - 13s 86ms/step - loss: 25.5730 - accuracy: 0.8017 - val_loss: 2.5528 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 2/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.8820
# Epoch 2: val_accuracy did not improve from 0.25365
# 137/137 [==============================] - 11s 78ms/step - loss: 0.4781 - accuracy: 0.8820 - val_loss: 3.1131 - val_accuracy: 0.2536 - lr: 0.0100
# Epoch 3/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8905
# Epoch 3: val_accuracy improved from 0.25365 to 0.25547, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 85ms/step - loss: 0.4514 - accuracy: 0.8905 - val_loss: 2.1496 - val_accuracy: 0.2555 - lr: 0.0100
# Epoch 4/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.8893
# Epoch 4: val_accuracy improved from 0.25547 to 0.71533, saving model to best_model_1280.h5
# 137/137 [==============================] - 11s 83ms/step - loss: 0.4296 - accuracy: 0.8893 - val_loss: 0.6430 - val_accuracy: 0.7153 - lr: 0.0100
# Epoch 5/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.8916
# Epoch 5: val_accuracy improved from 0.71533 to 0.90146, saving model to best_model_1280.h5
# 137/137 [==============================] - 12s 84ms/step - loss: 0.4117 - accuracy: 0.8916 - val_loss: 0.3326 - val_accuracy: 0.9015 - lr: 0.0100
# Epoch 6/100
# 137/137 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0
100
# 137/137 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9722
# Epoch 57: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 81ms/step - loss: 0.1228 - accuracy: 0.9722 - val_loss: 0.5260 - val_accuracy: 0.9261 - lr: 3.1250e-04
# Epoch 58/100
# 137/137 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9713Restoring model weights from the end of the best epoch: 38.
#
# Epoch 58: val_accuracy did not improve from 0.92701
# 137/137 [==============================] - 11s 81ms/step - loss: 0.1257 - accuracy: 0.9713 - val_loss: 0.5043 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 58: early stopping

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, confusion_matrix
import math

k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=1)

# Convert back to DataFrames if needed (assuming X_train is still a numpy array)
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)

# Result collection lists
ACC_collection = []
BACC_collection = []
Sn_collection = []
Sp_collection = []
MCC_collection = []
AUC_collection = []

# Function to train the model for each fold
def ESM_CNN(X_train_CV, y_train_CV, X_valid_CV, y_valid_CV):
    # Train the model with the training fold
    model = train_model(X_train_CV, y_train_CV, X_valid_CV, y_valid_CV)
    return model

# Cross-validation loop
for train_index, test_index in kf.split(y_train):
    X_train_CV, X_valid_CV = X_train.iloc[train_index, :], X_train.iloc[test_index, :]
    y_train_CV, y_valid_CV = y_train.iloc[train_index], y_train.iloc[test_index]

    # Train the model for this fold
    model = ESM_CNN(X_train_CV, y_train_CV, X_valid_CV, y_valid_CV)
    
    # Load the best model
    saved_model = load_model('best_model_1280.h5')
    
    # Predict probabilities
    predicted_probabilities = saved_model.predict(X_valid_CV, batch_size=1)
    
    # Convert probabilities to class predictions
    predicted_class = (predicted_probabilities > 0.5).astype(int)
    
    # Compute confusion matrix
    y_true = y_valid_CV.values
    TN, FP, FN, TP = confusion_matrix(y_true, predicted_class).ravel()
    
    # Compute metrics
    ACC = (TP + TN) / (TP + TN + FP + FN)
    Sn = TP / (TP + FN)
    Sp = TN / (TN + FP)
    MCC = (TP * TN - FP * FN) / math.sqrt((TP + FP) * (TP + FN) * (TN + FP) * (TN + FN))
    BACC = 0.5 * (Sn + Sp)
    AUC = roc_auc_score(y_true, predicted_probabilities)
    
    # Append metrics to collection lists
    ACC_collection.append(ACC)
    Sn_collection.append(Sn)
    Sp_collection.append(Sp)
    MCC_collection.append(MCC)
    BACC_collection.append(BACC)
    AUC_collection.append(AUC)

# Display the results for each fold
print("Average Accuracy:", np.mean(ACC_collection))
print("Average Balanced Accuracy:", np.mean(BACC_collection))
print("Average Sensitivity (Sn):", np.mean(Sn_collection))
print("Average Specificity (Sp):", np.mean(Sp_collection))
print("Average MCC:", np.mean(MCC_collection))
print("Average AUC:", np.mean(AUC_collection))
# Out:
# Epoch 1/100
# 124/124 [==============================] - ETA: 0s - loss: 17.3673 - accuracy: 0.8022
# Epoch 1: val_accuracy improved from -inf to 0.24601, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 124/124 [==============================] - 11s 84ms/step - loss: 17.3673 - accuracy: 0.8022 - val_loss: 12.5658 - val_accuracy: 0.2460 - lr: 0.0100
# Epoch 2/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8808
# Epoch 2: val_accuracy did not improve from 0.24601
# 124/124 [==============================] - 10s 78ms/step - loss: 0.4802 - accuracy: 0.8808 - val_loss: 12.7800 - val_accuracy: 0.2460 - lr: 0.0100
# Epoch 3/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8889
# Epoch 3: val_accuracy did not improve from 0.24601
# 124/124 [==============================] - 10s 78ms/step - loss: 0.4602 - accuracy: 0.8889 - val_loss: 7.3825 - val_accuracy: 0.2460 - lr: 0.0100
# Epoch 4/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8922
# Epoch 4: val_accuracy improved from 0.24601 to 0.26424, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 84ms/step - loss: 0.4221 - accuracy: 0.8922 - val_loss: 1.8019 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 5/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4297 - accuracy: 0.8907
# Epoch 5: val_accuracy improved from 0.26424 to 0.86560, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 84ms/step - loss: 0.4297 - accuracy: 0.8907 - val_loss: 0.3595 - val_accuracy: 0.8656 - lr: 0.0100
# Epoch 6/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8950
# Epoch 6: val_accuracy improved from 0.86560 to 0.90888, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 82ms/step - loss: 0.4324 - accuracy: 0.8950 - val_loss: 0.2302 - val_accuracy: 0.9089 - lr: 0.0100
# Epoch 7/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8958
# Epoch 7: val_accuracy did not improve from 0.90888
# 124/124 [==============================] - 10s 78ms/step - loss: 0.4132 - accuracy: 0.8958 - val_loss: 0.2627 - val_accuracy: 0.9089 - lr: 0.0100
# Epoch 8/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.8940
# Epoch 8: val_accuracy did not improve from 0.90888
# 124/124 [==============================] - 10s 79ms/step - loss: 0.4230 - accuracy: 0.8940 - val_loss: 0.2946 - val_accuracy: 0.9043 - lr: 0.0100
# Epoch 9/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8950
# Epoch 9: val_accuracy improved from 0.90888 to 0.91344, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 84ms/step - loss: 0.4288 - accuracy: 0.8950 - val_loss: 0.2344 - val_accuracy: 0.9134 - lr: 0.0100
# Epoch 10/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.9067
# Epoch 10: val_accuracy improved from 0.91344 to 0.92483, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 84ms/step - loss: 0.3878 - accuracy: 0.9067 - val_loss: 0.2189 - val_accuracy: 0.9248 - lr: 0.0050
# Epoch 11/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.9125
# Epoch 11: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 79ms/step - loss: 0.3634 - accuracy: 0.9125 - val_loss: 0.2215 - val_accuracy: 0.9226 - lr: 0.0050
# Epoch 12/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3517 - accuracy: 0.9133
# Epoch 12: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 81ms/step - loss: 0.3517 - accuracy: 0.9133 - val_loss: 0.2420 - val_accuracy: 0.9226 - lr: 0.0050
# Epoch 13/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.9153
# Epoch 13: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3443 - accuracy: 0.9153 - val_loss: 0.2250 - val_accuracy: 0.9089 - lr: 0.0050
# Epoch 14/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.9173
# Epoch 14: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.3542 - accuracy: 0.9173 - val_loss: 0.2837 - val_accuracy: 0.9112 - lr: 0.0050
# Epoch 15/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.9064
# Epoch 15: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.3777 - accuracy: 0.9064 - val_loss: 0.3710 - val_accuracy: 0.9089 - lr: 0.0050
# Epoch 16/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.9184
# Epoch 16: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.3293 - accuracy: 0.9184 - val_loss: 0.2193 - val_accuracy: 0.9112 - lr: 0.0050
# Epoch 17/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.9189
# Epoch 17: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.3393 - accuracy: 0.9189 - val_loss: 0.2193 - val_accuracy: 0.9089 - lr: 0.0050
# Epoch 18/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.9184
# Epoch 18: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.3411 - accuracy: 0.9184 - val_loss: 0.2343 - val_accuracy: 0.9089 - lr: 0.0050
# Epoch 19/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.
val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 79ms/step - loss: 0.1748 - accuracy: 0.9587 - val_loss: 0.3252 - val_accuracy: 0.9271 - lr: 0.0012
# Epoch 39/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9584
# Epoch 39: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1851 - accuracy: 0.9584 - val_loss: 0.3296 - val_accuracy: 0.9180 - lr: 0.0012
# Epoch 40/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9612
# Epoch 40: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1704 - accuracy: 0.9612 - val_loss: 0.3559 - val_accuracy: 0.9271 - lr: 6.2500e-04
# Epoch 41/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9620
# Epoch 41: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1676 - accuracy: 0.9620 - val_loss: 0.3748 - val_accuracy: 0.9226 - lr: 6.2500e-04
# Epoch 42/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9617
# Epoch 42: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1566 - accuracy: 0.9617 - val_loss: 0.3523 - val_accuracy: 0.9294 - lr: 6.2500e-04
# Epoch 43/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9632
# Epoch 43: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1552 - accuracy: 0.9632 - val_loss: 0.3769 - val_accuracy: 0.9294 - lr: 6.2500e-04
# Epoch 44/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9612
# Epoch 44: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 79ms/step - loss: 0.1551 - accuracy: 0.9612 - val_loss: 0.3429 - val_accuracy: 0.9294 - lr: 6.2500e-04
# Epoch 45/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9681Restoring model weights from the end of the best epoch: 25.
#
# Epoch 45: val_accuracy did not improve from 0.93166
# 124/124 [==============================] - 10s 81ms/step - loss: 0.1432 - accuracy: 0.9681 - val_loss: 0.3621 - val_accuracy: 0.9271 - lr: 6.2500e-04
# Epoch 45: early stopping
# 439/439 [==============================] - 1s 2ms/step
# Epoch 1/100
# 124/124 [==============================] - ETA: 0s - loss: 20.6712 - accuracy: 0.8174
# Epoch 1: val_accuracy improved from -inf to 0.26424, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 124/124 [==============================] - 11s 86ms/step - loss: 20.6712 - accuracy: 0.8174 - val_loss: 4.7012 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 2/100
# 124/124 [==============================] - ETA: 0s - loss: 0.5039 - accuracy: 0.8773
# Epoch 2: val_accuracy did not improve from 0.26424
# 124/124 [==============================] - 9s 76ms/step - loss: 0.5039 - accuracy: 0.8773 - val_loss: 0.9624 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 3/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4685 - accuracy: 0.8796
# Epoch 3: val_accuracy did not improve from 0.26424
# 124/124 [==============================] - 10s 77ms/step - loss: 0.4685 - accuracy: 0.8796 - val_loss: 1.9279 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 4/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.8912
# Epoch 4: val_accuracy improved from 0.26424 to 0.62187, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 82ms/step - loss: 0.4544 - accuracy: 0.8912 - val_loss: 0.7963 - val_accuracy: 0.6219 - lr: 0.0100
# Epoch 5/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8889
# Epoch 5: val_accuracy improved from 0.62187 to 0.90661, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 82ms/step - loss: 0.4583 - accuracy: 0.8889 - val_loss: 0.2850 - val_accuracy: 0.9066 - lr: 0.0100
# Epoch 6/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4350 - accuracy: 0.8930
# Epoch 6: val_accuracy did not improve from 0.90661
# 124/124 [==============================] - 9s 77ms/step - loss: 0.4350 - accuracy: 0.8930 - val_loss: 0.2670 - val_accuracy: 0.8815 - lr: 0.0100
# Epoch 7/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8849
# Epoch 7: val_accuracy improved from 0.90661 to 0.91800, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 83ms/step - loss: 0.4408 - accuracy: 0.8849 - val_loss: 0.2572 - val_accuracy: 0.9180 - lr: 0.0100
# Epoch 8/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.8862
# Epoch 8: val_accuracy improved from 0.91800 to 0.92027, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 83ms/step - loss: 0.4525 - accuracy: 0.8862 - val_loss: 0.2421 - val_accuracy: 0.9203 - lr: 0.0100
# Epoch 9/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0
100
# 124/124 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.9293
# Epoch 27: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 9s 76ms/step - loss: 0.2915 - accuracy: 0.9293 - val_loss: 0.2480 - val_accuracy: 0.9089 - lr: 0.0025
# Epoch 28/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.9300
# Epoch 28: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 79ms/step - loss: 0.3106 - accuracy: 0.9300 - val_loss: 0.2439 - val_accuracy: 0.9089 - lr: 0.0025
# Epoch 29/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.9296
# Epoch 29: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.2943 - accuracy: 0.9298 - val_loss: 0.2388 - val_accuracy: 0.9112 - lr: 0.0025
# Epoch 30/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9412Restoring model weights from the end of the best epoch: 10.
#
# Epoch 30: val_accuracy did not improve from 0.92483
# 124/124 [==============================] - 10s 78ms/step - loss: 0.2681 - accuracy: 0.9412 - val_loss: 0.2406 - val_accuracy: 0.9134 - lr: 0.0012
# Epoch 30: early stopping
# 439/439 [==============================] - 1s 2ms/step
# Epoch 1/100
# 124/124 [==============================] - ETA: 0s - loss: 18.5136 - accuracy: 0.7989
# Epoch 1: val_accuracy improved from -inf to 0.26424, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 124/124 [==============================] - 11s 86ms/step - loss: 18.5136 - accuracy: 0.7989 - val_loss: 2.6325 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 2/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4918 - accuracy: 0.8747
# Epoch 2: val_accuracy did not improve from 0.26424
# 124/124 [==============================] - 9s 76ms/step - loss: 0.4918 - accuracy: 0.8747 - val_loss: 2.5862 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 3/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4563 - accuracy: 0.8780
# Epoch 3: val_accuracy did not improve from 0.26424
# 124/124 [==============================] - 9s 76ms/step - loss: 0.4563 - accuracy: 0.8780 - val_loss: 1.8701 - val_accuracy: 0.2642 - lr: 0.0100
# Epoch 4/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.4121 - accuracy: 0.8918
# Epoch 4: val_accuracy improved from 0.26424 to 0.51025, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 82ms/step - loss: 0.4114 - accuracy: 0.8920 - val_loss: 0.8073 - val_accuracy: 0.5103 - lr: 0.0100
# Epoch 5/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8887
# Epoch 5: val_accuracy improved from 0.51025 to 0.91344, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 81ms/step - loss: 0.4284 - accuracy: 0.8887 - val_loss: 0.2685 - val_accuracy: 0.9134 - lr: 0.0100
# Epoch 6/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4177 - accuracy: 0.8948
# Epoch 6: val_accuracy improved from 0.91344 to 0.91572, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 81ms/step - loss: 0.4177 - accuracy: 0.8948 - val_loss: 0.2951 - val_accuracy: 0.9157 - lr: 0.0100
# Epoch 7/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.9047
# Epoch 7: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3885 - accuracy: 0.9047 - val_loss: 0.2498 - val_accuracy: 0.9134 - lr: 0.0100
# Epoch 8/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.9014
# Epoch 8: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3927 - accuracy: 0.9014 - val_loss: 0.2642 - val_accuracy: 0.9043 - lr: 0.0100
# Epoch 9/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.9049
# Epoch 9: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 9s 77ms/step - loss: 0.3752 - accuracy: 0.9049 - val_loss: 0.2756 - val_accuracy: 0.9134 - lr: 0.0100
# Epoch 10/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.9105
# Epoch 10: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 10s 77ms/step - loss: 0.3358 - accuracy: 0.9105 - val_loss: 0.2847 - val_accuracy: 0.8998 - lr: 0.0050
# Epoch 11/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3132 - accuracy: 0.9149
# Epoch 11: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3128 - accuracy: 0.9151 - val_loss: 0.2455 - val_accuracy: 0.9157 - lr: 0.0050
# Epoch 12/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.9194
# Epoch 12: val_accuracy did not improve from 0.91572
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3134 - accuracy: 0.9194 - val_loss: 0.2634 - val_accuracy: 0.9157 - lr: 0.0050
# Epoch 13/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.9184
# Epoch 13: val_accuracy improved from 0.91572 to 0.92711, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 82ms/step - loss: 0.3169 - accuracy: 0.9184 - val_loss: 0.2430 - val_accuracy: 0.9271 - lr: 0.0050
# Epoch 14/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.9161
# Epoch 14: val_accuracy improved from 0.92711 to 0.92938, saving model to best_model_1280.h5
# 124/124 [==============================] - 10s 81ms/step - loss: 0.3155 - accuracy: 0.9161 - val_loss: 0.2394 - val_accuracy: 0.9294 - lr: 0.0050
# Epoch 15/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3118 - accuracy: 0.9174
# Epoch 15: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3113 - accuracy: 0.9176 - val_loss: 0.2403 - val_accuracy: 0.9203 - lr: 0.0050
# Epoch 16/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3097 - accuracy: 0.9192
# Epoch 16: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3092 - accuracy: 0.9194 - val_loss: 0.2483 - val_accuracy: 0.9180 - lr: 0.0050
# Epoch 17/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.9181
# Epoch 17: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3130 - accuracy: 0.9181 - val_loss: 0.2726 - val_accuracy: 0.9066 - lr: 0.0050
# Epoch 18/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3006 - accuracy: 0.9248
# Epoch 18: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 76ms/step - loss: 0.3022 - accuracy: 0.9244 - val_loss: 0.2584 - val_accuracy: 0.9134 - lr: 0.0050
# Epoch 19/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.9173
# Epoch 19: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 77ms/step - loss: 0.3165 - accuracy: 0.9173 - val_loss: 0.2342 - val_accuracy: 0.9134 - lr: 0.0050
# Epoch 20/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.9222
# Epoch 20: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 77ms/step - loss: 0.3081 - accuracy: 0.9222 - val_loss: 0.2392 - val_accuracy: 0.9203 - lr: 0.0025
# Epoch 21/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2685 - accuracy: 0.9317
# Epoch 21: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 76ms/step - loss: 0.2684 - accuracy: 0.9315 - val_loss: 0.3006 - val_accuracy: 0.8793 - lr: 0.0025
# Epoch 22/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9298
# Epoch 22: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 77ms/step - loss: 0.2589 - accuracy: 0.9298 - val_loss: 0.2720 - val_accuracy: 0.9066 - lr: 0.0025
# Epoch 23/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.9369
# Epoch 23: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 10s 77ms/step - loss: 0.2550 - accuracy: 0.9369 - val_loss: 0.2996 - val_accuracy: 0.8975 - lr: 0.0025
# Epoch 24/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9356
# Epoch 24: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 10s 77ms/step - loss: 0.2535 - accuracy: 0.9356 - val_loss: 0.2597 - val_accuracy: 0.9203 - lr: 0.0025
# Epoch 25/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9379
# Epoch 25: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2537 - accuracy: 0.9379 - val_loss: 0.2650 - val_accuracy: 0.9226 - lr: 0.0025
# Epoch 26/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.9343
# Epoch 26: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 10s 78ms/step - loss: 0.2421 - accuracy: 0.9343 - val_loss: 0.2709 - val_accuracy: 0.9157 - lr: 0.0025
# Epoch 27/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9397
# Epoch 27: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 10s 78ms/step - loss: 0.2364 - accuracy: 0.9397 - val_loss: 0.3027 - val_accuracy: 0.9112 - lr: 0.0025
# Epoch 28/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9333
# Epoch 28: val_accuracy did not improve from 0.92938
# 124/124 [==============================] - 9s 77ms/step - loss: 0.2499 - accuracy: 0.9333 - val_loss: 0.2562 - val_accuracy: 0.9203 - lr: 0.0025
# Epoch 29/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.
100
# 124/124 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9404
# Epoch 27: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.2503 - accuracy: 0.9404 - val_loss: 0.2607 - val_accuracy: 0.9155 - lr: 0.0025
# Epoch 28/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9414
# Epoch 28: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.2464 - accuracy: 0.9414 - val_loss: 0.2459 - val_accuracy: 0.9110 - lr: 0.0025
# Epoch 29/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9437
# Epoch 29: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.2289 - accuracy: 0.9437 - val_loss: 0.2410 - val_accuracy: 0.9041 - lr: 0.0025
# Epoch 30/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9483
# Epoch 30: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.2028 - accuracy: 0.9483 - val_loss: 0.2565 - val_accuracy: 0.9132 - lr: 0.0012
# Epoch 31/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9501
# Epoch 31: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1990 - accuracy: 0.9501 - val_loss: 0.2892 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 32/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9587
# Epoch 32: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1819 - accuracy: 0.9587 - val_loss: 0.2442 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 33/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9546
# Epoch 33: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.1894 - accuracy: 0.9546 - val_loss: 0.2696 - val_accuracy: 0.9132 - lr: 0.0012
# Epoch 34/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9551
# Epoch 34: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.1814 - accuracy: 0.9551 - val_loss: 0.3291 - val_accuracy: 0.8973 - lr: 0.0012
# Epoch 35/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9529
# Epoch 35: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1934 - accuracy: 0.9529 - val_loss: 0.2523 - val_accuracy: 0.9087 - lr: 0.0012
# Epoch 36/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9589
# Epoch 36: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1791 - accuracy: 0.9589 - val_loss: 0.2646 - val_accuracy: 0.9132 - lr: 0.0012
# Epoch 37/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9541
# Epoch 37: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 77ms/step - loss: 0.1748 - accuracy: 0.9541 - val_loss: 0.2312 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 38/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9559
# Epoch 38: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 80ms/step - loss: 0.1770 - accuracy: 0.9559 - val_loss: 0.3198 - val_accuracy: 0.9132 - lr: 0.0012
# Epoch 39/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9569
# Epoch 39: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1741 - accuracy: 0.9569 - val_loss: 0.3410 - val_accuracy: 0.9041 - lr: 0.0012
# Epoch 40/100
# 124/124 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9597Restoring model weights from the end of the best epoch: 20.
#
# Epoch 40: val_accuracy did not improve from 0.92009
# 124/124 [==============================] - 10s 78ms/step - loss: 0.1676 - accuracy: 0.9597 - val_loss: 0.3343 - val_accuracy: 0.9064 - lr: 6.2500e-04
# Epoch 40: early stopping
# 438/438 [==============================] - 1s 2ms/step
# Epoch 1/100
# 124/124 [==============================] - ETA: 0s - loss: 28.2671 - accuracy: 0.7779
# Epoch 1: val_accuracy improved from -inf to 0.24886, saving model to best_model_1280.h5
# C:\Users\Nandan\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 124/124 [==============================] - 11s 85ms/step - loss: 28.2671 - accuracy: 0.7779 - val_loss: 0.6950 - val_accuracy: 0.2489 - lr: 0.0100
# Epoch 2/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.5157 - accuracy: 0.8679
# Epoch 2: val_accuracy did not improve from 0.24886
# 124/124 [==============================] - 10s 78ms/step - loss: 0.5146 - accuracy: 0.8682 - val_loss: 0.7018 - val_accuracy: 0.2443 - lr: 0.0100
# Epoch 3/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.4633 - accuracy: 0.8679
# Epoch 3: val_accuracy improved from 0.24886 to 0.64840, saving model to best_model_1280.h5
# ...
# Epoch 12: val_accuracy did not improve from 0.90411
# 124/124 [==============================] - 10s 81ms/step - loss: 0.4057 - accuracy: 0.8913 - val_loss: 0.3181 - val_accuracy: 0.8995 - lr: 0.0050
# Epoch 13/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.4445 - accuracy: 0.8958
# Epoch 13: val_accuracy improved from 0.90411 to 0.90639, saving model to best_model_1280.h5
# 124/124 [==============================] - 11s 86ms/step - loss: 0.4439 - accuracy: 0.8961 - val_loss: 0.3062 - val_accuracy: 0.9064 - lr: 0.0050
# Epoch 14/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.4063 - accuracy: 0.9004
# Epoch 14: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 81ms/step - loss: 0.4062 - accuracy: 0.9004 - val_loss: 0.3364 - val_accuracy: 0.9064 - lr: 0.0050
# Epoch 15/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.4249 - accuracy: 0.8984
# Epoch 15: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 80ms/step - loss: 0.4253 - accuracy: 0.8981 - val_loss: 0.3116 - val_accuracy: 0.9064 - lr: 0.0050
# Epoch 16/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3790 - accuracy: 0.9032
# Epoch 16: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 81ms/step - loss: 0.3790 - accuracy: 0.9032 - val_loss: 0.3172 - val_accuracy: 0.8973 - lr: 0.0050
# Epoch 17/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3972 - accuracy: 0.8986
# Epoch 17: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 81ms/step - loss: 0.3969 - accuracy: 0.8986 - val_loss: 0.2997 - val_accuracy: 0.8995 - lr: 0.0050
# Epoch 18/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4291 - accuracy: 0.8951
# Epoch 18: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 80ms/step - loss: 0.4291 - accuracy: 0.8951 - val_loss: 0.3458 - val_accuracy: 0.8995 - lr: 0.0050
# Epoch 19/100
# 124/124 [==============================] - ETA: 0s - loss: 0.4031 - accuracy: 0.9075
# Epoch 19: val_accuracy did not improve from 0.90639
# 124/124 [==============================] - 10s 79ms/step - loss: 0.4031 - accuracy: 0.9075 - val_loss: 0.3348 - val_accuracy: 0.9041 - lr: 0.0050
# Epoch 20/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3866 - accuracy: 0.9156
# Epoch 20: val_accuracy improved from 0.90639 to 0.91096, saving model to best_model_1280.h5
# 124/124 [==============================] - 11s 86ms/step - loss: 0.3866 - accuracy: 0.9156 - val_loss: 0.3161 - val_accuracy: 0.9110 - lr: 0.0025
# Epoch 21/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.9222
# Epoch 21: val_accuracy did not improve from 0.91096
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3437 - accuracy: 0.9222 - val_loss: 0.3215 - val_accuracy: 0.9064 - lr: 0.0025
# Epoch 22/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.9090
# Epoch 22: val_accuracy did not improve from 0.91096
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3752 - accuracy: 0.9090 - val_loss: 0.3274 - val_accuracy: 0.9018 - lr: 0.0025
# Epoch 23/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.9174
# Epoch 23: val_accuracy did not improve from 0.91096
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3563 - accuracy: 0.9174 - val_loss: 0.3077 - val_accuracy: 0.9110 - lr: 0.0025
# Epoch 24/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.9141
# Epoch 24: val_accuracy improved from 0.91096 to 0.91324, saving model to best_model_1280.h5
# 124/124 [==============================] - 11s 86ms/step - loss: 0.3542 - accuracy: 0.9141 - val_loss: 0.3083 - val_accuracy: 0.9132 - lr: 0.0025
# Epoch 25/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.9120
# Epoch 25: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 81ms/step - loss: 0.3488 - accuracy: 0.9120 - val_loss: 0.2953 - val_accuracy: 0.9018 - lr: 0.0025
# Epoch 26/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.9163
# Epoch 26: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3714 - accuracy: 0.9163 - val_loss: 0.3042 - val_accuracy: 0.9132 - lr: 0.0025
# Epoch 27/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.9181
# Epoch 27: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3516 - accuracy: 0.9181 - val_loss: 0.3321 - val_accuracy: 0.9087 - lr: 0.0025
# Epoch 28/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.9100
# Epoch 28: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3603 - accuracy: 0.9100 - val_loss: 0.2896 - val_accuracy: 0.8927 - lr: 0.0025
# Epoch 29/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.9027
# Epoch 29: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3865 - accuracy: 0.9027 - val_loss: 0.3101 - val_accuracy: 0.9041 - lr: 0.0025
# Epoch 30/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3184 - accuracy: 0.9235
# Epoch 30: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3179 - accuracy: 0.9237 - val_loss: 0.3457 - val_accuracy: 0.9064 - lr: 0.0012
# Epoch 31/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9262
# Epoch 31: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3109 - accuracy: 0.9262 - val_loss: 0.3403 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 32/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.9200
# Epoch 32: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3108 - accuracy: 0.9202 - val_loss: 0.3445 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 33/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3042 - accuracy: 0.9256
# Epoch 33: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3042 - accuracy: 0.9255 - val_loss: 0.3533 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 34/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.9247
# Epoch 34: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3065 - accuracy: 0.9247 - val_loss: 0.3796 - val_accuracy: 0.9132 - lr: 0.0012
# Epoch 35/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.3099 - accuracy: 0.9238
# Epoch 35: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3109 - accuracy: 0.9234 - val_loss: 0.3165 - val_accuracy: 0.9087 - lr: 0.0012
# Epoch 36/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3002 - accuracy: 0.9237
# Epoch 36: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3002 - accuracy: 0.9237 - val_loss: 0.4297 - val_accuracy: 0.8973 - lr: 0.0012
# Epoch 37/100
# 124/124 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.9245
# Epoch 37: val_accuracy did not improve from 0.91324
# 124/124 [==============================] - 10s 80ms/step - loss: 0.3014 - accuracy: 0.9245 - val_loss: 0.3506 - val_accuracy: 0.9064 - lr: 0.0012
# Epoch 38/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.9295
# Epoch 38: val_accuracy improved from 0.91324 to 0.91553, saving model to best_model_1280.h5
# 124/124 [==============================] - 11s 86ms/step - loss: 0.2877 - accuracy: 0.9295 - val_loss: 0.3590 - val_accuracy: 0.9155 - lr: 0.0012
# Epoch 39/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2939 - accuracy: 0.9306
# Epoch 39: val_accuracy did not improve from 0.91553
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2934 - accuracy: 0.9308 - val_loss: 0.3359 - val_accuracy: 0.9110 - lr: 0.0012
# Epoch 40/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9298
# Epoch 40: val_accuracy did not improve from 0.91553
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2779 - accuracy: 0.9298 - val_loss: 0.3459 - val_accuracy: 0.9064 - lr: 6.2500e-04
# Epoch 41/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9250
# Epoch 41: val_accuracy did not improve from 0.91553
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2954 - accuracy: 0.9250 - val_loss: 0.3711 - val_accuracy: 0.9155 - lr: 6.2500e-04
# Epoch 42/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9321
# Epoch 42: val_accuracy did not improve from 0.91553
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2648 - accuracy: 0.9321 - val_loss: 0.3461 - val_accuracy: 0.9087 - lr: 6.2500e-04
# Epoch 43/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.9354
# Epoch 43: val_accuracy improved from 0.91553 to 0.92237, saving model to best_model_1280.h5
# 124/124 [==============================] - 11s 86ms/step - loss: 0.2617 - accuracy: 0.9354 - val_loss: 0.3982 - val_accuracy: 0.9224 - lr: 6.2500e-04
# Epoch 44/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.9272
# Epoch 44: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2879 - accuracy: 0.9272 - val_loss: 0.3694 - val_accuracy: 0.9064 - lr: 6.2500e-04
# Epoch 45/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2652 - accuracy: 0.9365
# Epoch 45: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2647 - accuracy: 0.9366 - val_loss: 0.3982 - val_accuracy: 0.9178 - lr: 6.2500e-04
# Epoch 46/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9349
# Epoch 46: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2681 - accuracy: 0.9349 - val_loss: 0.4001 - val_accuracy: 0.9155 - lr: 6.2500e-04
# Epoch 47/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9369
# Epoch 47: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2599 - accuracy: 0.9369 - val_loss: 0.4178 - val_accuracy: 0.9110 - lr: 6.2500e-04
# Epoch 48/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9402
# Epoch 48: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2501 - accuracy: 0.9402 - val_loss: 0.4515 - val_accuracy: 0.9132 - lr: 6.2500e-04
# Epoch 49/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9364
# Epoch 49: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2738 - accuracy: 0.9364 - val_loss: 0.5165 - val_accuracy: 0.9087 - lr: 6.2500e-04
# Epoch 50/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9313
# Epoch 50: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2689 - accuracy: 0.9313 - val_loss: 0.4490 - val_accuracy: 0.9178 - lr: 3.1250e-04
# Epoch 51/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2574 - accuracy: 0.9378
# Epoch 51: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2570 - accuracy: 0.9379 - val_loss: 0.3967 - val_accuracy: 0.9132 - lr: 3.1250e-04
# Epoch 52/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9389
# Epoch 52: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2482 - accuracy: 0.9389 - val_loss: 0.3958 - val_accuracy: 0.9132 - lr: 3.1250e-04
# Epoch 53/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2430 - accuracy: 0.9416
# Epoch 53: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2426 - accuracy: 0.9417 - val_loss: 0.4690 - val_accuracy: 0.9201 - lr: 3.1250e-04
# Epoch 54/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9435
# Epoch 54: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2462 - accuracy: 0.9435 - val_loss: 0.4322 - val_accuracy: 0.9064 - lr: 3.1250e-04
# Epoch 55/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9414
# Epoch 55: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2383 - accuracy: 0.9414 - val_loss: 0.4504 - val_accuracy: 0.9110 - lr: 3.1250e-04
# Epoch 56/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.9414
# Epoch 56: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2412 - accuracy: 0.9414 - val_loss: 0.4707 - val_accuracy: 0.9155 - lr: 3.1250e-04
# Epoch 57/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.9409
# Epoch 57: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2439 - accuracy: 0.9409 - val_loss: 0.4807 - val_accuracy: 0.9224 - lr: 3.1250e-04
# Epoch 58/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9420
# Epoch 58: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2409 - accuracy: 0.9420 - val_loss: 0.4513 - val_accuracy: 0.9201 - lr: 3.1250e-04
# Epoch 59/100
# 123/124 [============================>.] - ETA: 0s - loss: 0.2446 - accuracy: 0.9431
# Epoch 59: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2453 - accuracy: 0.9427 - val_loss: 0.4903 - val_accuracy: 0.9178 - lr: 3.1250e-04
# Epoch 60/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.9409
# Epoch 60: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2369 - accuracy: 0.9409 - val_loss: 0.4780 - val_accuracy: 0.9201 - lr: 1.5625e-04
# Epoch 61/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9414
# Epoch 61: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 81ms/step - loss: 0.2388 - accuracy: 0.9414 - val_loss: 0.4695 - val_accuracy: 0.9178 - lr: 1.5625e-04
# Epoch 62/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9445
# Epoch 62: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2318 - accuracy: 0.9445 - val_loss: 0.4809 - val_accuracy: 0.9201 - lr: 1.5625e-04
# Epoch 63/100
# 124/124 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9447Restoring model weights from the end of the best epoch: 43.
#
# Epoch 63: val_accuracy did not improve from 0.92237
# 124/124 [==============================] - 10s 80ms/step - loss: 0.2301 - accuracy: 0.9447 - val_loss: 0.4893 - val_accuracy: 0.9178 - lr: 1.5625e-04
# Epoch 63: early stopping
# 438/438 [==============================] - 1s 2ms/step
# Average Accuracy: 0.9281310783120625
# Average Balanced Accuracy: 0.8985817327633564
# Average Sensitivity (Sn): 0.8377980352766551
# Average Specificity (Sp): 0.9593654302500578
# Average MCC: 0.809294926429111
# Average AUC: 0.9502147088294292

# %%
# Display the results for each fold with mean and standard deviation
print("Accuracy: Mean =", np.mean(ACC_collection), ", Std =", np.std(ACC_collection))
print("Balanced Accuracy: Mean =", np.mean(BACC_collection), ", Std =", np.std(BACC_collection))
print("Sensitivity (Sn): Mean =", np.mean(Sn_collection), ", Std =", np.std(Sn_collection))
print("Specificity (Sp): Mean =", np.mean(Sp_collection), ", Std =", np.std(Sp_collection))
print("MCC: Mean =", np.mean(MCC_collection), ", Std =", np.std(MCC_collection))
print("AUC: Mean =", np.mean(AUC_collection), ", Std =", np.std(AUC_collection))
# Out:
# Accuracy: Mean = 0.9281310783120625 , Std = 0.009373552754328912
# Balanced Accuracy: Mean = 0.8985817327633564 , Std = 0.015307497729815803
# Sensitivity (Sn): Mean = 0.8377980352766551 , Std = 0.03415118325399747
# Specificity (Sp): Mean = 0.9593654302500578 , Std = 0.013860292931974307
# MCC: Mean = 0.809294926429111 , Std = 0.027758012403472886
# AUC: Mean = 0.9502147088294292 , Std = 0.012468456811801523

# %%
# Evaluate on the test dataset
predicted_probas_test = saved_model.predict(X_test, batch_size=32)
best_threshold_test, best_mcc_test = optimize_threshold(y_test, predicted_probas_test)
predicted_classes_test = (predicted_probas_test > best_threshold_test).astype(int)

# Calculate metrics for the test dataset with optimized threshold
accuracy_test = accuracy_score(y_test, predicted_classes_test)
sensitivity_test = recall_score(y_test, predicted_classes_test)  # Sensitivity (Recall)
TN_test, FP_test, FN_test, TP_test = confusion_matrix(y_test, predicted_classes_test).ravel()
specificity_test = TN_test / (TN_test + FP_test)  # Corrected Specificity calculation
MCC_test = matthews_corrcoef(y_test, predicted_classes_test)
auc_test = roc_auc_score(y_test, predicted_classes_test)

# Compute the correct balanced accuracy
balanced_accuracy_test = (sensitivity_test + specificity_test) / 2

# Print the adjusted results for the test dataset
print("\nOptimized Test Dataset Results:")
print(f"Accuracy (ACC): {accuracy_test}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_test}")
print(f"Sensitivity (Sn): {sensitivity_test}")
print(f"Specificity (Sp): {specificity_test}")
print(f"MCC: {MCC_test}")
print(f"AUC: {auc_test}")
print(f"True Positives (TP): {TP_test}")
print(f"False Positives (FP): {FP_test}")
print(f"True Negatives (TN): {TN_test}")
print(f"False Negatives (FN): {FN_test}")

# Print the total positive and total negative
total_positive = np.sum(y_test)
total_negative = len(y_test) - total_positive
print(f"Total Positive: {total_positive}")
print(f"Total Negative: {total_negative}")
# Out:
# 35/35 [==============================] - 0s 8ms/step
#
# Optimized Test Dataset Results:
# Accuracy (ACC): 0.9288321167883211
# Balanced Accuracy (BACC): 0.8929570280206153
# Sensitivity (Sn): 0.8201438848920863
# Specificity (Sp): 0.9657701711491442
# MCC: 0.8081918754774996
# AUC: 0.8929570280206153
# True Positives (TP): 228
# False Positives (FP): 28
# True Negatives (TN): 790
# False Negatives (FN): 50
# Total Positive: 278
# Total Negative: 818

# %%
# Evaluate on the external dataset (KELM)
dataset_external = pd.read_csv('kelm_dataset.csv', na_filter=False)
X_external_data_name = 'kelm_dataset_esm2_t33_650M_UR50D_unified_1280_dimension.csv'
X_external_data = pd.read_csv(X_external_data_name, header=0, index_col=0, delimiter=',')
X_external = np.array(X_external_data)
y_external = np.array(dataset_external['label'])

# Normalize the external dataset
X_external_normalized = scaler.transform(X_external)

# Predict probabilities for external dataset
predicted_probas_ext = saved_model.predict(X_external_normalized, batch_size=32)
best_threshold_ext, best_mcc_ext = optimize_threshold(y_external, predicted_probas_ext)
predicted_classes_ext = (predicted_probas_ext > best_threshold_ext).astype(int)

# Calculate metrics for the external dataset with optimized threshold
accuracy_ext = accuracy_score(y_external, predicted_classes_ext)
sensitivity_ext = recall_score(y_external, predicted_classes_ext)  # Sensitivity (Recall)
TN_ext, FP_ext, FN_ext, TP_ext = confusion_matrix(y_external, predicted_classes_ext).ravel()
specificity_ext = TN_ext / (TN_ext + FP_ext)  # Corrected Specificity calculation
MCC_ext = matthews_corrcoef(y_external, predicted_classes_ext)
auc_ext = roc_auc_score(y_external, predicted_classes_ext)

# Compute the correct balanced accuracy
balanced_accuracy_ext = (sensitivity_ext + specificity_ext) / 2

# Print the adjusted results for the external dataset
print("\nOptimized External Dataset (KELM) Results:")
print(f"Accuracy (ACC): {accuracy_ext}")
print(f"Balanced Accuracy (BACC): {balanced_accuracy_ext}")
print(f"Sensitivity (Sn): {sensitivity_ext}")
print(f"Specificity (Sp): {specificity_ext}")
print(f"MCC: {MCC_ext}")
print(f"AUC: {auc_ext}")
print(f"True Positives (TP): {TP_ext}")
print(f"False Positives (FP): {FP_ext}")
print(f"True Negatives (TN): {TN_ext}")
print(f"False Negatives (FN): {FN_ext}")

# Print the total positive and total negative
total_positive_ext = np.sum(y_external)
total_negative_ext = len(y_external) - total_positive_ext
print(f"Total Positive: {total_positive_ext}")
print(f"Total Negative: {total_negative_ext}")
# Out:
# 6/6 [==============================] - 0s 10ms/step
#
# Optimized External Dataset (KELM) Results:
# Accuracy (ACC): 0.8958333333333334
# Balanced Accuracy (BACC): 0.8958333333333333
# Sensitivity (Sn): 0.84375
# Specificity (Sp): 0.9479166666666666
# MCC: 0.7959970056457051
# AUC: 0.8958333333333333
# True Positives (TP): 81
# False Positives (FP): 5
# True Negatives (TN): 91
# False Negatives (FN): 15
# Total Positive: 96
# Total Negative: 96
